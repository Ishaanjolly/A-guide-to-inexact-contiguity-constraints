# %% [markdown]
# ## Enumerate all feasible district plans on synthetic grid graphs with uniform population
#
# ### Tests 4×4 grid graph across a range of population deviations.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

ROOT_DIR = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT_DIR))

# %%
import os
import pandas as pd

from src.mip import multi_district_mip
from src.utils import make_grid_graph
from src.draw import draw_graph

os.makedirs("../../results", exist_ok=True)

# %% [markdown]
# #### SET EXPERIMENT PARAMETERS

# %%
DEVIATIONS = [0, 1, 2]
CONTIGUITY = ["tree", "dist", "dag", "cut"]
POOL_SIZE = 1000000
TIME_LIMIT = 3600
POOL_SEARCH = 2

# %% [markdown]
# ## 4×4 Grid

# %%
G4 = make_grid_graph(4, 4)


print(f"4×4 grid: {G4.number_of_nodes()} nodes, {G4.number_of_edges()} edges")
# Out:
# 4×4 grid: 16 nodes, 24 edges

# %%
draw_graph(G4)

# %%
## ROOT SELECTION
roots = [0, 3, 12, 15]

# %%
results = []

for deviation in DEVIATIONS:
    for contiguity in CONTIGUITY:
        print(f"\ndeviation={deviation} | contiguity={contiguity}")

        metrics, _ = multi_district_mip(
            G=G4,
            deviation_persons=deviation,
            contiguity=contiguity,
            roots=roots,
            k=len(roots),
            pool_size=POOL_SIZE,
            pool_search=POOL_SEARCH,
            time_limit=TIME_LIMIT,
        )
        metrics.update(
            {"grid": "4x4", "deviation": deviation, "contiguity": contiguity}
        )

        results.append(
            {key: value for key, value in metrics.items() if key != "districts"}
        )

df = pd.DataFrame(results)
df.to_csv("../../results/small_4x4_enumeration.csv", index=False)
# Out:
# deviation=0 | contiguity=tree
# Using L, U, k = 4 4 4
# Set parameter Username
# Academic license - for non-commercial use only - expires 2027-04-02
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 312 nonzeros (Min)
# Model fingerprint: 0x37bab122
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 82 rows and 60 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 4 columns, 5 nonzeros
# Variable types: 0 continuous, 4 integer (4 binary)
#
# Root relaxation: objective 0.000000e+00, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 13 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 7: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=0 | contiguity=dist
# Using L, U, k = 4 4 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 348 nonzeros (Min)
# Model fingerprint: 0xef3abd70
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 28 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 56 rows, 48 columns, 200 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 190 nodes (396 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 33: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=0 | contiguity=dag
# Using L, U, k = 4 4 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 348 nonzeros (Min)
# Model fingerprint: 0xef3abd70
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 28 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 56 rows, 48 columns, 200 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 190 nodes (396 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 33: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=0 | contiguity=cut
# Using L, U, k = 4 4 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 24 rows, 64 columns and 192 nonzeros (Min)
# Model fingerprint: 0x6cac2a22
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
#
# Presolve removed 8 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 16 rows, 48 columns, 96 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 21 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    4          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0   13          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0   12          -    0.00000      -     -    0s
#      0     0    0.00000    0   16          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    6          -    0.00000      -     -    0s
#      0     0    0.00000    0    6          -    0.00000      -     -    0s
#      0     2    0.00000    0    4          -    0.00000      -     -    0s
# *   27    22               5       0.0000000    0.00000  0.00%   7.5    0s
#
# Optimal solution found at node 43 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#     43    23          -    6               -    0.00000      -   7.7    0s
#
# Cutting planes:
#   Lazy constraints: 94
#
# Explored 672 nodes (2496 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 33: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 1641, time in user-callback 0.02 sec
#
# deviation=1 | contiguity=tree
# Using L, U, k = 3 5 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 312 nonzeros (Min)
# Model fingerprint: 0xf0cf7895
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 54 rows and 41 columns
# Presolve time: 0.00s
# Presolved: 30 rows, 23 columns, 119 nonzeros
# Variable types: 0 continuous, 23 integer (23 binary)
#
# Root relaxation: objective 0.000000e+00, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 218 nodes (84 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 91: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=1 | contiguity=dist
# Using L, U, k = 3 5 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 348 nonzeros (Min)
# Model fingerprint: 0xf6748491
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 24 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 60 rows, 48 columns, 248 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 1593 nodes (726 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 597: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=1 | contiguity=dag
# Using L, U, k = 3 5 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 348 nonzeros (Min)
# Model fingerprint: 0xf6748491
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 24 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 60 rows, 48 columns, 248 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 46 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 1593 nodes (726 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 597: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=1 | contiguity=cut
# Using L, U, k = 3 5 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 24 rows, 64 columns and 192 nonzeros (Min)
# Model fingerprint: 0xe2b966ea
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
#
# Presolve removed 4 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 48 columns, 144 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    4          -    0.00000      -     -    0s
# *    0     0               0       0.0000000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Cutting planes:
#   Cover: 1
#   Inf proof: 3
#   Lazy constraints: 127
#
# Explored 4836 nodes (6432 simplex iterations) in 0.17 seconds (0.02 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 597: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 10517, time in user-callback 0.12 sec
#
# deviation=2 | contiguity=tree
# Using L, U, k = 2 6 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 312 nonzeros (Min)
# Model fingerprint: 0x35ffc494
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 39 rows and 30 columns
# Presolve time: 0.00s
# Presolved: 45 rows, 34 columns, 156 nonzeros
# Variable types: 0 continuous, 34 integer (34 binary)
#
# Root relaxation: objective 0.000000e+00, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 709 nodes (227 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 329: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=2 | contiguity=dist
# Using L, U, k = 2 6 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 348 nonzeros (Min)
# Model fingerprint: 0x1da58782
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 24 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 60 rows, 48 columns, 224 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 43 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 4989 nodes (2085 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 2257: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=2 | contiguity=dag
# Using L, U, k = 2 6 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 348 nonzeros (Min)
# Model fingerprint: 0x1da58782
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 24 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 60 rows, 48 columns, 224 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 43 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 4989 nodes (2085 simplex iterations) in 0.07 seconds (0.01 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 2257: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=2 | contiguity=cut
# Using L, U, k = 2 6 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 24 rows, 64 columns and 192 nonzeros (Min)
# Model fingerprint: 0x7378b273
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#
# Presolve removed 4 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 48 columns, 144 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    6          -    0.00000      -     -    0s
#      0     0    0.00000    0    6          -    0.00000      -     -    0s
#      0     0    0.00000    0   12          -    0.00000      -     -    0s
#      0     0    0.00000    0   14          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0   14          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    8          -    0.00000      -     -    0s
#      0     0    0.00000    0    8          -    0.00000      -     -    0s
# H    0     0                       0.0000000    0.00000  0.00%     -    0s
#      0     2    0.00000    0    8    0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 1 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      1     4          -    1               -    0.00000      -   2.0    0s
#
# Cutting planes:
#   Cover: 2
#   Inf proof: 3
#   Lazy constraints: 154
#
# Explored 9445 nodes (7371 simplex iterations) in 0.70 seconds (0.03 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 2297: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 21497, time in user-callback 0.56 sec
