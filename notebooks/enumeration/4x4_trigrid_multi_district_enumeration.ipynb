# %% [markdown]
# ## Enumerate all feasible district plans on synthetic grid graphs with uniform population
#
# ### Tests 4×4 trigrid graph across a range of population deviations.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

ROOT_DIR = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT_DIR))

# %%
import os
import pandas as pd

from src.mip import multi_district_mip
from src.utils import make_trigrid_graph
from src.draw import draw_graph

os.makedirs("../../results", exist_ok=True)

# %% [markdown]
# #### SET EXPERIMENT PARAMETERS

# %%
DEVIATIONS = [0, 1, 2]
CONTIGUITY = ["tree", "dist", "dag", "cut"]
POOL_SIZE = 1000000
TIME_LIMIT = 3600
POOL_SEARCH = 2

# %% [markdown]
# ## 4×4 Grid

# %%
G4 = make_trigrid_graph(4, 4)


print(f"4×4 grid: {G4.number_of_nodes()} nodes, {G4.number_of_edges()} edges")
# Out:
# 4×4 grid: 16 nodes, 33 edges

# %%
draw_graph(G4)

# %%
## ROOT SELECTION
roots = [0, 3, 12, 15]

# %%
results = []

for deviation in DEVIATIONS:
    for contiguity in CONTIGUITY:
        print(f"\ndeviation={deviation} | contiguity={contiguity}")

        metrics, _ = multi_district_mip(
            G=G4,
            deviation_persons=deviation,
            contiguity=contiguity,
            roots=roots,
            k=len(roots),
            pool_size=POOL_SIZE,
            pool_search=POOL_SEARCH,
            time_limit=TIME_LIMIT,
        )
        metrics.update(
            {"grid": "4x4", "deviation": deviation, "contiguity": contiguity}
        )

        results.append(
            {key: value for key, value in metrics.items() if key != "districts"}
        )

df = pd.DataFrame(results)
df.to_csv("../../results/small_4x4_tri_enumeration.csv", index=False)
# Out:
# deviation=0 | contiguity=tree
# Using L, U, k = 4 4 4
# Set parameter Username
# Academic license - for non-commercial use only - expires 2027-04-02
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 312 nonzeros (Min)
# Model fingerprint: 0x86ebe0b0
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
#
# Presolve removed 69 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 61 nonzeros
# Variable types: 0 continuous, 16 integer (16 binary)
# Found heuristic solution: objective 0.0000000
#
# Root relaxation: objective 0.000000e+00, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    2    0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 1
#
# Explored 74 nodes (26 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 20: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=0 | contiguity=dist
# Using L, U, k = 4 4 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 342 nonzeros (Min)
# Model fingerprint: 0xf5a1607e
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 34 rows and 20 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 44 columns, 184 nonzeros
# Variable types: 0 continuous, 44 integer (44 binary)
#
# Root relaxation: objective 0.000000e+00, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 278 nodes (365 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 61: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=0 | contiguity=dag
# Using L, U, k = 4 4 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 384 nonzeros (Min)
# Model fingerprint: 0x8e26e02e
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
#
# Presolve removed 32 rows and 18 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 46 columns, 207 nonzeros
# Variable types: 0 continuous, 46 integer (46 binary)
# Found heuristic solution: objective 0.0000000
#
# Root relaxation: objective 0.000000e+00, 42 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 385 nodes (592 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 65: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=0 | contiguity=cut
# Using L, U, k = 4 4 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 24 rows, 64 columns and 192 nonzeros (Min)
# Model fingerprint: 0x6cac2a22
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
#
# Presolve removed 8 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 16 rows, 48 columns, 96 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 20 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0   12          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0   17          -    0.00000      -     -    0s
#      0     0    0.00000    0    4          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    8          -    0.00000      -     -    0s
#      0     0    0.00000    0   10          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0   18          -    0.00000      -     -    0s
#      0     0    0.00000    0   18          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0   10          -    0.00000      -     -    0s
# H    0     0                       0.0000000    0.00000  0.00%     -    0s
#      0     2    0.00000    0    8    0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 1 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      1     4    0.00000    1   13          -    0.00000      -   8.0    0s
#
# Cutting planes:
#   Cover: 3
#   Lazy constraints: 85
#
# Explored 947 nodes (3643 simplex iterations) in 0.08 seconds (0.01 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 71: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 2233, time in user-callback 0.05 sec
#
# deviation=1 | contiguity=tree
# Using L, U, k = 3 5 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 312 nonzeros (Min)
# Model fingerprint: 0x68b69e1e
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 43 rows and 32 columns
# Presolve time: 0.00s
# Presolved: 41 rows, 32 columns, 164 nonzeros
# Variable types: 0 continuous, 32 integer (32 binary)
#
# Root relaxation: objective 0.000000e+00, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 808 nodes (158 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 349: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=1 | contiguity=dist
# Using L, U, k = 3 5 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 342 nonzeros (Min)
# Model fingerprint: 0x1f6200ad
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 28 rows and 18 columns
# Presolve time: 0.00s
# Presolved: 56 rows, 46 columns, 230 nonzeros
# Variable types: 0 continuous, 46 integer (46 binary)
#
# Root relaxation: objective 0.000000e+00, 31 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 2422 nodes (1386 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 1021: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=1 | contiguity=dag
# Using L, U, k = 3 5 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 384 nonzeros (Min)
# Model fingerprint: 0xace21cfc
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 27 rows and 17 columns
# Presolve time: 0.00s
# Presolved: 57 rows, 47 columns, 254 nonzeros
# Variable types: 0 continuous, 47 integer (47 binary)
#
# Root relaxation: objective 0.000000e+00, 48 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 2667 nodes (1389 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 1137: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=1 | contiguity=cut
# Using L, U, k = 3 5 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 24 rows, 64 columns and 192 nonzeros (Min)
# Model fingerprint: 0xe2b966ea
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
#
# Presolve removed 4 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 48 columns, 144 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
# *    0     0               0       0.0000000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Cutting planes:
#   Cover: 6
#   Inf proof: 2
#   Lazy constraints: 115
#
# Explored 7758 nodes (10808 simplex iterations) in 0.46 seconds (0.03 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 1267: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 17045, time in user-callback 0.36 sec
#
# deviation=2 | contiguity=tree
# Using L, U, k = 2 6 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 312 nonzeros (Min)
# Model fingerprint: 0xab79a8d1
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 34 rows and 24 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 40 columns, 169 nonzeros
# Variable types: 0 continuous, 40 integer (40 binary)
#
# Root relaxation: objective 0.000000e+00, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 2729 nodes (319 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 1285: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=2 | contiguity=dist
# Using L, U, k = 2 6 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 342 nonzeros (Min)
# Model fingerprint: 0xdea92c46
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 26 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 58 rows, 48 columns, 217 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 32 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Explored 7522 nodes (2064 simplex iterations) in 0.10 seconds (0.02 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 3638: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=2 | contiguity=dag
# Using L, U, k = 2 6 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 84 rows, 64 columns and 384 nonzeros (Min)
# Model fingerprint: 0x4a346517
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#
# Found heuristic solution: objective 0.0000000
# Presolve removed 26 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 58 rows, 48 columns, 239 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 34 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.00000    0.00000  0.00%     -    0s
#
# Optimal solution found at node 0 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     0          -    0               -    0.00000      -     -    0s
#      0     2          -    0               -    0.00000      -     -    0s
#
# Cutting planes:
#   Inf proof: 1
#
# Explored 9043 nodes (3021 simplex iterations) in 0.15 seconds (0.02 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 4208: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# deviation=2 | contiguity=cut
# Using L, U, k = 2 6 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 1000000
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1000000
# PoolSearchMode  2
#
# Optimize a model with 24 rows, 64 columns and 192 nonzeros (Min)
# Model fingerprint: 0x7378b273
# Model has 0 linear objective coefficients
# Variable types: 0 continuous, 64 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
#
# Presolve removed 4 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 48 columns, 144 nonzeros
# Variable types: 0 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 0.000000e+00, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0    -          -    0.00000      -     -    0s
#      0     0    0.00000    0   10          -    0.00000      -     -    0s
#      0     0    0.00000    0    8          -    0.00000      -     -    0s
#      0     0    0.00000    0    4          -    0.00000      -     -    0s
#      0     0    0.00000    0    8          -    0.00000      -     -    0s
#      0     0    0.00000    0    4          -    0.00000      -     -    0s
#      0     0    0.00000    0    4          -    0.00000      -     -    0s
#      0     2    0.00000    0    4          -    0.00000      -     -    0s
# H    6     8                       0.0000000    0.00000  0.00%   3.8    0s
#
# Optimal solution found at node 7 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      7    16    0.00000    3    8          -    0.00000      -   4.4    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 8
#   Inf proof: 8
#   Lazy constraints: 120
#
# Explored 16500 nodes (13380 simplex iterations) in 1.59 seconds (0.06 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 4832: 0 0 0 ... 0
# No other solutions better than 0
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 38133, time in user-callback 1.30 sec
