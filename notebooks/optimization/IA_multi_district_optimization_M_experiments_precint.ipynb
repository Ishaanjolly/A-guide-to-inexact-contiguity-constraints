# %% [markdown]
# ## Iowa Optimization — PRECINT LEVEL
#
# This notebook runs multi-district MIP optimization experiments across PRECINT LEVEL
#
# | Metric | Edge weight | M |
# |---|---|---|
# | `hop_M` | 1 + {0, M, M²} | number of nodes |
# | `euclidean_M` | eucl(i,j) + {0, M, M²} | two-sweep diameter |
#
# The penalty tier is determined by GEOID20 prefix matching:
# - `GEOID20[:11]` match → same tract (no penalty)
# - `GEOID20[:5]` match → same county, different tract (+M)
# - Otherwise → different county (+M²)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

ROOT_DIR = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT_DIR))

import os

from src.read import read_graph_from_json
from src.experiment import run_optimization_experiment

os.makedirs("../../results", exist_ok=True)

# %% [markdown]
# ### Experiment parameters

# %%
GRAPH_LEVELS = ["vtd"]
DISTANCE_METRICS = ["hop", "euclidean", "hop_M", "euclidean_M"]

K = 4
DEVIATIONS = [50]
CONTIGUITY = ["tree", "dist", "dag", "cut"]
TIME_LIMIT = 3600

OBJECTIVES = ["euclidean_moi", "cut_edges"]

total_combinations = len(GRAPH_LEVELS) * len(DISTANCE_METRICS)
print(f"Graph levels     : {GRAPH_LEVELS}")
print(f"Distance metrics : {DISTANCE_METRICS}")
print(f"Combinations     : {total_combinations}")
print(f"Experiments each : {len(DEVIATIONS) * len(CONTIGUITY)} × objectives")
# Out:
# Graph levels     : ['vtd']
# Distance metrics : ['hop', 'euclidean', 'hop_M', 'euclidean_M']
# Combinations     : 4
# Experiments each : 4 × objectives

# %% [markdown]
# ### Run all combinations

# %%
all_results = {}

for graph_level in GRAPH_LEVELS:
    print(f"Loading graph: IA_{graph_level}.json")
    G = read_graph_from_json(f"../../data/IA_{graph_level}.json", state="IA")
    has_coords = "X" in G.nodes[next(iter(G.nodes))]
    coord_key = "coords" if has_coords else "no_coords"
    print(
        f"  {G.number_of_nodes()} nodes, {G.number_of_edges()} edges | coords: {has_coords}"
    )

    for dist_metric in DISTANCE_METRICS:
        label = f"IA_{graph_level}_{dist_metric}"
        results_file = f"../../results/{label}_optimization.csv"

        df = run_optimization_experiment(
            G_base=G,
            deviations=DEVIATIONS,
            contiguity_models=CONTIGUITY,
            objectives=OBJECTIVES,
            k=K,
            distance_metric=dist_metric,
            time_limit=TIME_LIMIT,
            results_file=results_file,
        )

        df["graph_level"] = graph_level
        df["distance_metric"] = dist_metric
        all_results[label] = df

print(" All combinations complete.")
# Out:
# Loading graph: IA_vtd.json
#   2536 nodes, 5946 edges | coords: True
# Selected roots: [2048, 1015, 1551, 1956]
# Distance metric: hop
#
# Total experiments: 8
# Results will be saved to: ../../results/IA_vtd_hop_optimization.csv
# ========================================================================
#
# [1/8] deviation=50 | contiguity=tree (dist: hop) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-11-24
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 12684 rows, 10144 columns and 50600 nonzeros (Min)
# Model fingerprint: 0x5b5b2cf0
# Model has 10084 linear objective coefficients
# Variable types: 0 continuous, 10144 integer (10144 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [7e-01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 3177 rows and 2768 columns
# Presolve time: 2.57s
# Presolved: 9507 rows, 7376 columns, 37709 nonzeros
# Variable types: 0 continuous, 7376 integer (7376 binary)
# Found heuristic solution: objective 1.362858e+07
#
# Root relaxation: objective 9.285023e+06, 1561 iterations, 0.08 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9285023.05    0   92 1.3629e+07 9285023.05  31.9%     -    2s
# H    0     0                    9316893.5132 9285023.05  0.34%     -    2s
# H    0     0                    9302875.5536 9285023.05  0.19%     -    2s
# H    0     0                    9298963.9117 9285023.05  0.15%     -    2s
# H    0     0                    9298908.0369 9285023.05  0.15%     -    2s
# H    0     0                    9298170.7979 9285023.05  0.14%     -    2s
# H    0     0                    9298140.6331 9285023.05  0.14%     -    3s
#      0     0 9297572.37    0    8 9298140.63 9297572.37  0.01%     -    3s
#      0     0 9297572.37    0    3 9298140.63 9297572.37  0.01%     -    3s
# H    0     0                    9298137.9059 9297572.37  0.01%     -    3s
# H    0     0                    9298121.7433 9297572.37  0.01%     -    3s
#      0     0 9297598.37    0    7 9298121.74 9297598.37  0.01%     -    3s
# H    0     0                    9298108.0397 9297598.37  0.01%     -    3s
#      0     0 9297622.82    0   11 9298108.04 9297622.82  0.01%     -    3s
# H    0     0                    9298093.4002 9297622.82  0.01%     -    3s
#      0     0 9297622.82    0    4 9298093.40 9297622.82  0.01%     -    3s
# H    0     0                    9297854.9557 9297622.82  0.00%     -    3s
#      0     0 9297629.06    0    9 9297854.96 9297629.06  0.00%     -    3s
#      0     0 9297629.06    0    4 9297854.96 9297629.06  0.00%     -    3s
#      0     0 9297629.06    0   11 9297854.96 9297629.06  0.00%     -    3s
#      0     0 9297632.20    0   12 9297854.96 9297632.20  0.00%     -    3s
#      0     0 9297649.85    0   15 9297854.96 9297649.85  0.00%     -    3s
#      0     0 9297654.06    0   17 9297854.96 9297654.06  0.00%     -    3s
#      0     0 9297654.59    0   18 9297854.96 9297654.59  0.00%     -    3s
#      0     0 9297662.85    0   22 9297854.96 9297662.85  0.00%     -    3s
#      0     0 9297663.28    0   22 9297854.96 9297663.28  0.00%     -    3s
#      0     0 9297663.28    0   22 9297854.96 9297663.28  0.00%     -    3s
# H    0     0                    9297804.7842 9297663.28  0.00%     -    3s
#      0     0 9297668.93    0    4 9297804.78 9297668.93  0.00%     -    3s
#      0     0 9297668.93    0   11 9297804.78 9297668.93  0.00%     -    3s
#      0     0 9297668.93    0   17 9297804.78 9297668.93  0.00%     -    3s
#      0     0 9297668.93    0   21 9297804.78 9297668.93  0.00%     -    3s
#      0     0 9297668.93    0   22 9297804.78 9297668.93  0.00%     -    3s
#      0     0 9297668.93    0   24 9297804.78 9297668.93  0.00%     -    3s
#      0     0 9297668.93    0   24 9297804.78 9297668.93  0.00%     -    3s
#      0     2 9297668.93    0   24 9297804.78 9297668.93  0.00%     -    3s
# H  261   180                    9297778.6722 9297698.92  0.00%   4.7    3s
# *  677     0              14    9297763.9421 9297712.92  0.00%   4.4    3s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 2
#   Cover: 16
#   MIR: 14
#   StrongCG: 7
#   GUB cover: 5
#   Inf proof: 15
#
# Explored 799 nodes (5389 simplex iterations) in 3.30 seconds (1.73 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 9.29776e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.297763942132e+06, best bound 9.297763942132e+06, gap 0.0000%
#  Saved to ../../results/IA_vtd_hop_optimization.csv
#
# [2/8] deviation=50 | contiguity=tree (dist: hop) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 72144 rows, 63658 columns and 252764 nonzeros (Min)
# Model fingerprint: 0xa73d388e
# Model has 5946 linear objective coefficients
# Variable types: 0 continuous, 63658 integer (63658 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 10743 rows and 10725 columns
# Presolve time: 0.73s
# Presolved: 61401 rows, 52933 columns, 210874 nonzeros
# Variable types: 0 continuous, 52933 integer (52933 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    69220    9.4391669e+02   7.040266e+02   6.072712e+09      5s
#    91625    3.6365478e+02   0.000000e+00   1.263705e+04     10s
#   100141    2.3403008e+02   0.000000e+00   1.490964e+04     15s
#   107089    1.6790914e+02   0.000000e+00   1.012279e+05     20s
#   112914    1.4007179e+02   0.000000e+00   4.328176e+04     25s
#   119101    1.2735530e+02   0.000000e+00   2.098629e+04     30s
#   124581    1.2122227e+02   0.000000e+00   1.822342e+04     35s
#   129473    1.1309175e+02   0.000000e+00   2.281135e+04     40s
#   134715    1.0179557e+02   0.000000e+00   4.860952e+04     45s
#   139154    9.9498435e+01   0.000000e+00   1.289706e+05     50s
#   143610    9.5703241e+01   0.000000e+00   4.119984e+04     55s
#   147060    9.4610782e+01   0.000000e+00   7.037933e+04     60s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    52182    6.7490323e+00   0.000000e+00   0.000000e+00     65s
#
# Root relaxation: objective 6.749032e+00, 52182 iterations, 63.94 seconds (47.21 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    6.74903    0 10128          -    6.74903      -     -   70s
# H    0     0                    4039.0000000    6.74903   100%     - 3660s
#
# Explored 1 nodes (59635 simplex iterations) in 3660.30 seconds (165.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 4039
#
# Time limit reached
# Best objective 4.039000000000e+03, best bound 7.000000000000e+00, gap 99.8267%
#  Saved to ../../results/IA_vtd_hop_optimization.csv
#
# [3/8] deviation=50 | contiguity=dist (dist: hop) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 12684 rows, 10144 columns and 56794 nonzeros (Min)
# Model fingerprint: 0xec638f78
# Model has 10084 linear objective coefficients
# Variable types: 0 continuous, 10144 integer (10144 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [7e-01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 393 rows and 323 columns
# Presolve time: 0.46s
# Presolved: 12291 rows, 9821 columns, 55025 nonzeros
# Variable types: 0 continuous, 9821 integer (9821 binary)
#
# Root relaxation: objective 9.272280e+06, 2522 iterations, 0.18 seconds (0.51 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9272280.37    0   76          - 9272280.37      -     -    0s
# H    0     0                    9275340.4849 9272280.37  0.03%     -    0s
# H    0     0                    9273415.6519 9272280.37  0.01%     -    0s
# H    0     0                    9272438.4776 9272280.37  0.00%     -    0s
#      0     0 9272284.71    0    8 9272438.48 9272284.71  0.00%     -    0s
#      0     0 9272284.71    0    3 9272438.48 9272284.71  0.00%     -    0s
#      0     0 9272289.65    0    6 9272438.48 9272289.65  0.00%     -    0s
#      0     0 9272304.67    0    9 9272438.48 9272304.67  0.00%     -    0s
# H    0     0                    9272414.9207 9272304.98  0.00%     -    0s
#      0     0 9272305.54    0   10 9272414.92 9272305.54  0.00%     -    0s
#      0     0 9272319.85    0   15 9272414.92 9272319.85  0.00%     -    0s
#      0     0 9272320.25    0   15 9272414.92 9272320.25  0.00%     -    0s
#      0     0 9272323.24    0    3 9272414.92 9272323.24  0.00%     -    1s
#      0     0 9272323.24    0   16 9272414.92 9272323.24  0.00%     -    1s
#      0     0 9272323.24    0   15 9272414.92 9272323.24  0.00%     -    1s
#      0     0 9272323.24    0   18 9272414.92 9272323.24  0.00%     -    1s
# H    0     0                    9272411.7553 9272323.24  0.00%     -    1s
#      0     0 9268401.87    0   20 9268516.13 9268401.87  0.00%     -    0s
#      0     0 9268402.23    0   22 9268516.13 9268402.23  0.00%     -    0s
#      0     0 9268406.84    0   24 9268516.13 9268406.84  0.00%     -    0s
#      0     0 9268407.08    0   24 9268516.13 9268407.08  0.00%     -    0s
# H    0     0                    9268451.2281 9268407.31  0.00%     -    0s
#      0     0 9268407.31    0    3 9268451.23 9268407.31  0.00%     -    0s
#      0     0 9268407.31    0   13 9268451.23 9268407.31  0.00%     -    0s
#      0     0 9268407.31    0   16 9268451.23 9268407.31  0.00%     -    0s
#      0     0 9268407.60    0   16 9268451.23 9268407.60  0.00%     -    0s
#      0     0 9268408.15    0   19 9268451.23 9268408.15  0.00%     -    0s
#      0     0 9268409.51    0   21 9268451.23 9268409.51  0.00%     -    0s
#      0     0 9268411.39    0   23 9268451.23 9268411.39  0.00%     -    0s
#      0     0 9268411.66    0   23 9268451.23 9268411.66  0.00%     -    0s
#      0     2 9268412.50    0   23 9268451.23 9268412.50  0.00%     -    0s
# *  192    25              14    9268450.7846 9268425.02  0.00%   4.4    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 15
#   MIR: 8
#   StrongCG: 9
#   GUB cover: 4
#
# Explored 310 nodes (3503 simplex iterations) in 0.62 seconds (0.83 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 9.26845e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.268450784623e+06, best bound 9.268450784623e+06, gap 0.0000%
#  Saved to ../../results/IA_vtd_hop_optimization.csv
#
# [6/8] deviation=50 | contiguity=dag (dist: hop) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 72144 rows, 63658 columns and 266408 nonzeros (Min)
# Model fingerprint: 0x2f06b9c5
# Model has 5946 linear objective coefficients
# Variable types: 0 continuous, 63658 integer (63658 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 1666 rows and 1641 columns
# Presolve time: 0.64s
# Presolved: 70478 rows, 62017 columns, 258716 nonzeros
# Variable types: 0 continuous, 62017 integer (62017 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    66638    2.4368721e+03   5.000000e-01   8.602488e+06    972s
#    74542    2.1608513e+03   0.000000e+00   1.453960e+03    975s
#    82207    1.9518288e+03   0.000000e+00   6.381726e+04   2020s
#    94184    1.7047747e+03   0.000000e+00   9.978378e+04   2025s
#    95063    1.6895754e+03   0.000000e+00   8.996910e+04   3023s
#    98861    1.6281587e+03   0.000000e+00   1.234313e+05   3025s
#   105413    1.5120649e+03   0.000000e+00   2.815006e+08   3997s
#
#
# Root relaxation: time limit, 0 iterations, 3996.42 seconds (14.66 work units)
#
# Explored 1 nodes (0 simplex iterations) in 3997.27 seconds (16.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 0.000000000000e+00, gap -
#  Saved to ../../results/IA_vtd_hop_optimization.csv
#
# [7/8] deviation=50 | contiguity=cut (dist: N/A) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1
#
# Optimize a model with 2544 rows, 10144 columns and 30320 nonzeros (Min)
# Model fingerprint: 0x2b5e29b5
# Model has 10084 linear objective coefficients
# Variable types: 0 continuous, 10144 integer (10144 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [7e-01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 4 rows and 16 columns
# Presolve time: 0.01s
# Presolved: 2540 rows, 10128 columns, 30272 nonzeros
# Variable types: 0 continuous, 10128 integer (10128 binary)
#
# Root relaxation: objective 9.266797e+06, 2038 iterations, 0.08 seconds (0.34 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9266797.36    0    6          - 9266797.36      -     -    1s
#      0     0 9266797.36    0    6          - 9266797.36      -     -    2s
#      0     0 9266821.80    0    8          - 9266821.80      -     -    2s
# H    0     0                    9266992.0042 9266821.80  0.00%     -    2s
#      0     0 9266836.93    0   12 9266992.00 9266836.93  0.00%     -    2s
#      0     0 9266846.46    0   14 9266992.00 9266846.46  0.00%     -    2s
#      0     0 9266849.69    0   10 9266992.00 9266849.69  0.00%     -    2s
#      0     0 9266849.69    0    3 9266992.00 9266849.69  0.00%     -    2s
#      0     0 9266849.69    0   10 9266992.00 9266849.69  0.00%     -    2s
#      0     0 9266852.55    0   10 9266992.00 9266852.55  0.00%     -    2s
#      0     0 9266853.66    0   11 9266992.00 9266853.66  0.00%     -    2s
#      0     0 9266859.35    0   15 9266992.00 9266859.35  0.00%     -    2s
#      0     0 9266860.21    0   17 9266992.00 9266860.21  0.00%     -    2s
#      0     0 9266863.31    0   20 9266992.00 9266863.31  0.00%     -    2s
#      0     0 9266863.47    0   20 9266992.00 9266863.47  0.00%     -    2s
#      0     2 9266863.96    0   20 9266992.00 9266863.96  0.00%     -    2s
# H 1856  1302                    9266973.1689 9266882.22  0.00%   3.3    2s
# H 1856  1222                    9266963.8759 9266882.22  0.00%   3.3    2s
# H 2041  1109                    9266950.7822 9266882.22  0.00%   3.3    2s
# H 2531   867                    9266945.9607 9266893.99  0.00%   3.3    2s
# H 2531   823                    9266938.3379 9266893.99  0.00%   3.3    2s
# H 2531   782                    9266932.4853 9266893.99  0.00%   3.3    2s
# H 2531   743                    9266931.8405 9266893.99  0.00%   3.3    2s
# H 2531   705                    9266931.7595 9266893.99  0.00%   3.3    2s
#
# Cutting planes:
#   Gomory: 1
#   Lift-and-project: 2
#   Cover: 32
#   MIR: 10
#   StrongCG: 12
#   Flow cover: 6
#   GUB cover: 3
#   Inf proof: 1
#   Zero half: 2
#   RLT: 2
#
# Explored 3395 nodes (17068 simplex iterations) in 2.90 seconds (0.73 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 9.26693e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.266931759516e+06, best bound 9.266931759517e+06, gap 0.0000%
#
# User-callback calls 7364, time in user-callback 2.36 sec
#  Saved to ../../results/IA_vtd_hop_optimization.csv
#
# [8/8] deviation=50 | contiguity=cut (dist: N/A) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1
#
# Optimize a model with 62004 rows, 63658 columns and 232484 nonzeros (Min)
# Model fingerprint: 0xfa14a21b
# Model has 5946 linear objective coefficients
# Variable types: 0 continuous, 63658 integer (63658 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 58 rows and 34 columns
# Presolve time: 0.12s
# Presolved: 61946 rows, 63624 columns, 232256 nonzeros
# Variable types: 0 continuous, 63624 integer (63624 binary)
# Root relaxation presolved: 62743 rows, 63628 columns, 227656 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    55711    2.6704677e+03   0.000000e+00   6.704222e+03   1002s
#   106380    1.4539432e+03   0.000000e+00   1.212390e+04   1005s
#   119991    7.3602452e+02   0.000000e+00   1.862227e+06   2035s
#   137778    4.4286883e+02   0.000000e+00   1.300134e+05   2040s
#   138503    4.4275778e+02   0.000000e+00   2.106614e+05   2307s
#   146378    3.4777786e+02   0.000000e+00   5.431951e+04   2310s
#   155773    3.0500390e+02   0.000000e+00   2.718239e+05   3269s
#   157326    3.0372632e+02   0.000000e+00   1.303614e+05   3270s
#
#
# Root relaxation: time limit, 54174 iterations, 4263.27 seconds (27.51 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     - 4264s
#
# Cutting planes:
#   Lazy constraints: 801
#
# Explored 1 nodes (54174 simplex iterations) in 4264.16 seconds (27.88 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 0.000000000000e+00, gap -
#
# User-callback calls 306, time in user-callback 0.65 sec
#  Saved to ../../results/IA_vtd_hop_optimization.csv
# Selected roots: [2048, 1015, 1551, 1956]
# Distance metric: euclidean
# Setting Euclidean edge weights...
#
# Total experiments: 8
# Results will be saved to: ../../results/IA_vtd_euclidean_optimization.csv
# ========================================================================
#
# [1/8] deviation=50 | contiguity=tree (dist: euclidean) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 12684 rows, 10144 columns and 50600 nonzeros (Min)
# Model fingerprint: 0xd0db8174
# Model has 10084 linear objective coefficients
# Variable types: 0 continuous, 10144 integer (10144 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [7e-01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 2447 rows and 2229 columns
# Presolve time: 1.26s
# Presolved: 10237 rows, 7915 columns, 40261 nonzeros
# Variable types: 0 continuous, 7915 integer (7915 binary)
# Found heuristic solution: objective 1.095561e+07
#
# Root relaxation: objective 9.266904e+06, 1721 iterations, 0.07 seconds (0.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9266903.86    0    6 1.0956e+07 9266903.86  15.4%     -    1s
# H    0     0                    9267290.2342 9266903.86  0.00%     -    1s
#      0     0 9266926.74    0   11 9267290.23 9266926.74  0.00%     -    1s
#      0     0 9266926.74    0    3 9267290.23 9266926.74  0.00%     -    1s
# H    0     0                    9267197.0582 9266926.74  0.00%     -    1s
#      0     0 9266942.70    0    8 9267197.06 9266942.70  0.00%     -    1s
# H    0     0                    9267096.8405 9266947.06  0.00%     -    1s
#      0     0 9266952.69    0    9 9267096.84 9266952.69  0.00%     -    1s
#      0     0 9266956.23    0   11 9267096.84 9266956.23  0.00%     -    1s
#      0     0 9266956.33    0   12 9267096.84 9266956.33  0.00%     -    1s
#      0     0 9266964.54    0   15 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.54    0    3 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.54    0    8 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.54    0   13 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.54    0   15 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.54    0   11 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.83    0   18 9267096.84 9266964.83  0.00%     -    1s
#      0     0 9266965.20    0   17 9267096.84 9266965.20  0.00%     -    1s
#      0     0 9266967.09    0   24 9267096.84 9266967.09  0.00%     -    1s
#      0     0 9266967.45    0   24 9267096.84 9266967.45  0.00%     -    1s
# H    0     0                    9267092.9166 9266970.40  0.00%     -    1s
#      0     2 9266970.40    0   24 9267092.92 9266970.40  0.00%     -    1s
# H  299   291                    9267073.4689 9266978.38  0.00%   3.9    1s
# *  455   777              23    9267025.4125 9266978.38  0.00%   3.6    1s
# H 1292   777                    9267021.4886 9266978.38  0.00%   3.3    1s
#
# Cutting planes:
#   Lift-and-project: 2
#   Cover: 23
#   MIR: 21
#   StrongCG: 9
#   GUB cover: 4
#   Inf proof: 27
#   RLT: 3
#
# Explored 2303 nodes (9733 simplex iterations) in 1.61 seconds (1.75 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 9.26702e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.267021488587e+06, best bound 9.267021488587e+06, gap 0.0000%
#  Saved to ../../results/IA_vtd_euclidean_optimization.csv
#
# [2/8] deviation=50 | contiguity=tree (dist: euclidean) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 72144 rows, 63658 columns and 252764 nonzeros (Min)
# Model fingerprint: 0x3e4c400a
# Model has 5946 linear objective coefficients
# Variable types: 0 continuous, 63658 integer (63658 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 10348 rows and 10330 columns
# Presolve time: 0.37s
# Presolved: 61796 rows, 53328 columns, 211664 nonzeros
# Variable types: 0 continuous, 53328 integer (53328 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    70066    8.0086895e+02   6.086405e+02   1.619756e+09    967s
#    92294    4.7540899e+02   4.506050e+01   1.181914e+09    970s
#   105038    3.3136471e+02   0.000000e+00   3.585645e+05   2043s
#   110748    2.4208884e+02   0.000000e+00   1.478161e+04   2045s
#   121746    1.5658140e+02   0.000000e+00   1.500570e+05   2972s
#   128601    1.5049500e+02   0.000000e+00   1.585389e+05   2975s
#   134410    1.3616441e+02   0.000000e+00   5.188662e+05   4003s
#
#
# Root relaxation: time limit, 0 iterations, 4002.80 seconds (22.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    3649.0000000    0.00000   100%     - 4003s
#
# Explored 1 nodes (0 simplex iterations) in 4003.30 seconds (23.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 3649
#
# Time limit reached
# Best objective 3.649000000000e+03, best bound 0.000000000000e+00, gap 100.0000%
#  Saved to ../../results/IA_vtd_euclidean_optimization.csv
#
# [3/8] deviation=50 | contiguity=dist (dist: euclidean) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 12684 rows, 10144 columns and 50600 nonzeros (Min)
# Model fingerprint: 0xd0db8174
# Model has 10084 linear objective coefficients
# Variable types: 0 continuous, 10144 integer (10144 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [7e-01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 2447 rows and 2229 columns
# Presolve time: 1.27s
# Presolved: 10237 rows, 7915 columns, 40261 nonzeros
# Variable types: 0 continuous, 7915 integer (7915 binary)
# Found heuristic solution: objective 1.095561e+07
#
# Root relaxation: objective 9.266904e+06, 1721 iterations, 0.07 seconds (0.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9266903.86    0    6 1.0956e+07 9266903.86  15.4%     -    1s
# H    0     0                    9267290.2342 9266903.86  0.00%     -    1s
#      0     0 9266926.74    0   11 9267290.23 9266926.74  0.00%     -    1s
#      0     0 9266926.74    0    3 9267290.23 9266926.74  0.00%     -    1s
# H    0     0                    9267197.0582 9266926.74  0.00%     -    1s
#      0     0 9266942.70    0    8 9267197.06 9266942.70  0.00%     -    1s
# H    0     0                    9267096.8405 9266947.06  0.00%     -    1s
#      0     0 9266952.69    0    9 9267096.84 9266952.69  0.00%     -    1s
#      0     0 9266956.23    0   11 9267096.84 9266956.23  0.00%     -    1s
#      0     0 9266956.33    0   12 9267096.84 9266956.33  0.00%     -    1s
#      0     0 9266964.54    0   15 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.54    0    3 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.54    0    8 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.54    0   13 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.54    0   15 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.54    0   11 9267096.84 9266964.54  0.00%     -    1s
#      0     0 9266964.83    0   18 9267096.84 9266964.83  0.00%     -    1s
#      0     0 9266965.20    0   17 9267096.84 9266965.20  0.00%     -    1s
#      0     0 9266967.09    0   24 9267096.84 9266967.09  0.00%     -    1s
#      0     0 9266967.45    0   24 9267096.84 9266967.45  0.00%     -    1s
# H    0     0                    9267092.9166 9266970.40  0.00%     -    1s
#      0     2 9266970.40    0   24 9267092.92 9266970.40  0.00%     -    1s
# H  299   291                    9267073.4689 9266978.38  0.00%   3.9    1s
# *  455   777              23    9267025.4125 9266978.38  0.00%   3.6    1s
# H 1292   777                    9267021.4886 9266978.38  0.00%   3.3    1s
#
# Cutting planes:
#   Lift-and-project: 2
#   Cover: 23
#   MIR: 21
#   StrongCG: 9
#   GUB cover: 4
#   Inf proof: 27
#   RLT: 3
#
# Explored 2303 nodes (9733 simplex iterations) in 1.55 seconds (1.75 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 9.26702e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.267021488587e+06, best bound 9.267021488587e+06, gap 0.0000%
#  Saved to ../../results/IA_vtd_euclidean_optimization.csv
#
# [4/8] deviation=50 | contiguity=dist (dist: euclidean) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 72144 rows, 63658 columns and 252764 nonzeros (Min)
# Model fingerprint: 0x3e4c400a
# Model has 5946 linear objective coefficients
# Variable types: 0 continuous, 63658 integer (63658 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 10348 rows and 10330 columns
# Presolve time: 0.35s
# Presolved: 61796 rows, 53328 columns, 211664 nonzeros
# Variable types: 0 continuous, 53328 integer (53328 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#
# Concurrent spin time: 0.03s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   146385    6.7490323e+00   0.000000e+00   0.000000e+00   1305s
#
# Root relaxation: objective 6.749032e+00, 146385 iterations, 1304.76 seconds (226.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    6.74903    0 10128          -    6.74903      -     - 1310s
#      0     0    8.00804    0 10143          -    8.00804      -     - 1390s
#      0     0    8.00804    0 10143          -    8.00804      -     - 1429s
#      0     0    8.00804    0 10143          -    8.00804      -     - 1431s
#      0     2    8.00805    0 10143          -    8.00805      -     - 1439s
#      1     3    8.75823    1 10150          -    8.00805      -  2467 1445s
#      2     5    9.01092    2 10153          -    8.00805      -  1838 1497s
#      4     8   19.05444    2 10464          -    8.75844      -  8965 1616s
#      7     9   23.01171    3 10488          -    9.01092      - 14858 1673s
#     14    14   24.78075    4 10504          -   11.78485      -  8716 1743s
#     21    15   16.96680    5 10211          -   13.78590      -  8233 2208s
#     22    17   21.65388    5 10264          -   13.78590      -  8018 2288s
#     24    20   18.81211    5 10191          -   13.78590      -  7744 2370s
#     27    22   30.37543    6 10368          -   13.78590      -  7684 2499s
#     29    24   34.02602    7 10285          -   13.78590      -  7565 4335s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 31 nodes (402449 simplex iterations) in 4335.27 seconds (1229.47 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 1.400000000000e+01, gap -
#  Saved to ../../results/IA_vtd_euclidean_optimization.csv
#
# [7/8] deviation=50 | contiguity=cut (dist: N/A) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1
#
# Optimize a model with 2544 rows, 10144 columns and 30320 nonzeros (Min)
# Model fingerprint: 0x2b5e29b5
# Model has 10084 linear objective coefficients
# Variable types: 0 continuous, 10144 integer (10144 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [7e-01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 4 rows and 16 columns
# Presolve time: 0.02s
# Presolved: 2540 rows, 10128 columns, 30272 nonzeros
# Variable types: 0 continuous, 10128 integer (10128 binary)
#
# Root relaxation: objective 9.266797e+06, 2038 iterations, 0.13 seconds (0.34 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9266797.36    0    6          - 9266797.36      -     -    4s
#      0     0 9266797.36    0    6          - 9266797.36      -     -    5s
#      0     0 9266797.36    0    6          - 9266797.36      -     -    5s
#      0     0 9266821.80    0    8          - 9266821.80      -     -    5s
# H    0     0                    9266992.0042 9266821.80  0.00%     -    6s
#      0     0 9266836.93    0   12 9266992.00 9266836.93  0.00%     -    6s
#      0     0 9266846.46    0   14 9266992.00 9266846.46  0.00%     -    6s
#      0     0 9266849.69    0   10 9266992.00 9266849.69  0.00%     -    6s
#      0     0 9266849.69    0    3 9266992.00 9266849.69  0.00%     -    6s
#      0     0 9266849.69    0   10 9266992.00 9266849.69  0.00%     -    6s
#      0     0 9266852.55    0   10 9266992.00 9266852.55  0.00%     -    6s
#      0     0 9266853.66    0   11 9266992.00 9266853.66  0.00%     -    6s
#      0     0 9266859.35    0   15 9266992.00 9266859.35  0.00%     -    6s
#      0     0 9266860.21    0   17 9266992.00 9266860.21  0.00%     -    6s
#      0     0 9266863.31    0   20 9266992.00 9266863.31  0.00%     -    6s
#      0     0 9266863.47    0   20 9266992.00 9266863.47  0.00%     -    6s
#      0     2 9266863.96    0   20 9266992.00 9266863.96  0.00%     -    6s
# H 1856  1302                    9266973.1689 9266882.22  0.00%   3.3    6s
# H 1856  1222                    9266963.8759 9266882.22  0.00%   3.3    6s
# H 2041  1109                    9266950.7822 9266882.22  0.00%   3.3    6s
# H 2531   867                    9266945.9607 9266893.99  0.00%   3.3    7s
# H 2531   823                    9266938.3379 9266893.99  0.00%   3.3    7s
# H 2531   782                    9266932.4853 9266893.99  0.00%   3.3    7s
# H 2531   743                    9266931.8405 9266893.99  0.00%   3.3    7s
# H 2531   705                    9266931.7595 9266893.99  0.00%   3.3    7s
#
# Cutting planes:
#   Gomory: 1
#   Lift-and-project: 2
#   Cover: 32
#   MIR: 10
#   StrongCG: 12
#   Flow cover: 6
#   GUB cover: 3
#   Inf proof: 1
#   Zero half: 2
#   RLT: 2
#
# Explored 3395 nodes (17068 simplex iterations) in 7.71 seconds (0.73 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 9.26693e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.266931759516e+06, best bound 9.266931759517e+06, gap 0.0000%
#
# User-callback calls 7483, time in user-callback 6.31 sec
#  Saved to ../../results/IA_vtd_euclidean_optimization.csv
#
# [8/8] deviation=50 | contiguity=cut (dist: N/A) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1
#
# Optimize a model with 62004 rows, 63658 columns and 232484 nonzeros (Min)
# Model fingerprint: 0xfa14a21b
# Model has 5946 linear objective coefficients
# Variable types: 0 continuous, 63658 integer (63658 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 58 rows and 34 columns
# Presolve time: 0.26s
# Presolved: 61946 rows, 63624 columns, 232256 nonzeros
# Variable types: 0 continuous, 63624 integer (63624 binary)
# Root relaxation presolved: 62743 rows, 63628 columns, 227656 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.0000000e+00   3.720588e+04   1.674812e+09   1017s
#    88780    1.7876374e+03   0.000000e+00   1.509560e+05   1020s
#   107105    1.4094741e+03   0.000000e+00   7.078232e+04   1984s
#   110856    1.3761985e+03   0.000000e+00   5.544518e+04   1985s
#   130497    4.8972762e+02   0.000000e+00   2.284770e+05   3006s
#   141633    4.2789463e+02   0.000000e+00   7.179158e+04   3010s
#   153509    3.2087623e+02   0.000000e+00   9.336818e+05   3015s
#   153836    3.1603128e+02   0.000000e+00   7.456168e+05   3701s
#
#
# Root relaxation: time limit, 48971 iterations, 2683.61 seconds (19.60 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     - 3700s
#
# Cutting planes:
#   Lazy constraints: 801
#
# Explored 1 nodes (48971 simplex iterations) in 3700.55 seconds (19.96 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 0.000000000000e+00, gap -
#
# User-callback calls 326, time in user-callback 1016.45 sec
#  Saved to ../../results/IA_vtd_euclidean_optimization.csv
# Selected roots: [2048, 1015, 1551, 1956]
# Distance metric: hop_M
# Setting hierarchical hop-M edge weights...
#
# Total experiments: 8
# Results will be saved to: ../../results/IA_vtd_hop_M_optimization.csv
# ========================================================================
#
# [1/8] deviation=50 | contiguity=tree (dist: hop_M) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 12684 rows, 10144 columns and 50600 nonzeros (Min)
# Model fingerprint: 0xe24b4992
# Model has 10084 linear objective coefficients
# Variable types: 0 continuous, 10144 integer (10144 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [7e-01, 4e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 3295 rows and 2862 columns
# Presolve time: 1.39s
# Presolved: 9389 rows, 7282 columns, 37242 nonzeros
# Variable types: 0 continuous, 7282 integer (7282 binary)
# Found heuristic solution: objective 1.236049e+07
# Found heuristic solution: objective 1.029611e+07
#
# Root relaxation: objective 9.273321e+06, 1759 iterations, 0.06 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9273321.22    0    8 1.0296e+07 9273321.22  9.93%     -    1s
# H    0     0                    9273729.6274 9273321.22  0.00%     -    1s
#      0     0 9273380.54    0   23 9273729.63 9273380.54  0.00%     -    1s
#      0     0 9273380.54    0    4 9273729.63 9273380.54  0.00%     -    1s
# H    0     0                    9273595.3894 9273380.54  0.00%     -    1s
#      0     0 9273385.86    0   13 9273595.39 9273385.86  0.00%     -    1s
# H    0     0                    9273524.2888 9273389.25  0.00%     -    1s
#      0     0 9273396.66    0    8 9273524.29 9273396.66  0.00%     -    1s
#      0     0 9273401.28    0    9 9273524.29 9273401.28  0.00%     -    1s
#      0     0 9273401.32    0    8 9273524.29 9273401.32  0.00%     -    1s
#      0     0 9273405.41    0   10 9273524.29 9273405.41  0.00%     -    1s
# H    0     0                    9273516.5849 9273405.41  0.00%     -    1s
#      0     0 9273405.41    0    4 9273516.58 9273405.41  0.00%     -    1s
#      0     0 9273405.41    0    8 9273516.58 9273405.41  0.00%     -    1s
#      0     0 9273405.41    0   10 9273516.58 9273405.41  0.00%     -    1s
#      0     0 9273408.92    0   16 9273516.58 9273408.92  0.00%     -    1s
#      0     0 9273413.22    0   17 9273516.58 9273413.22  0.00%     -    1s
#      0     0 9273414.15    0   17 9273516.58 9273414.15  0.00%     -    1s
#      0     0 9273418.27    0   25 9273516.58 9273418.27  0.00%     -    1s
#      0     0 9273419.85    0   25 9273516.58 9273419.85  0.00%     -    1s
#      0     2 9273422.68    0   25 9273516.58 9273422.68  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 51
#   MIR: 18
#   StrongCG: 6
#   GUB cover: 3
#   Inf proof: 5
#   RLT: 2
#
# Explored 2281 nodes (9397 simplex iterations) in 1.73 seconds (1.68 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 9.27352e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.273516584933e+06, best bound 9.273516584933e+06, gap 0.0000%
#  Saved to ../../results/IA_vtd_hop_M_optimization.csv
#
# [2/8] deviation=50 | contiguity=tree (dist: hop_M) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 72144 rows, 63658 columns and 252764 nonzeros (Min)
# Model fingerprint: 0x061dd8e7
# Model has 5946 linear objective coefficients
# Variable types: 0 continuous, 63658 integer (63658 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 10752 rows and 10734 columns
# Presolve time: 0.42s
# Presolved: 61392 rows, 52924 columns, 210856 nonzeros
# Variable types: 0 continuous, 52924 integer (52924 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    90062    3.7506626e+02   1.288035e-03   1.350035e+07      5s
#   104723    1.8283868e+02   0.000000e+00   5.095388e+04     10s
#   111641    1.5838448e+02   0.000000e+00   1.185777e+04     15s
#   120443    1.2987327e+02   0.000000e+00   4.759541e+04     20s
#   126537    1.2302919e+02   0.000000e+00   6.033877e+04     25s
#   130852    1.1299800e+02   0.000000e+00   5.580120e+04     30s
#   134310    1.1246094e+02   0.000000e+00   8.795267e+04     35s
#   138216    1.1006104e+02   0.000000e+00   2.449671e+05     40s
#   140867    1.0942502e+02   0.000000e+00   3.968383e+05     45s
#   145475    1.0235982e+02   0.000000e+00   1.168531e+05     50s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    48608    6.7490323e+00   0.000000e+00   0.000000e+00     51s
#
# Root relaxation: objective 6.749032e+00, 48608 iterations, 50.67 seconds (41.76 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    6.74903    0 10128          -    6.74903      -     -   60s
