# %% [markdown]
# ## Iowa Optimization — Hierarchical M Experiments (Block Group, Tract, Block)
#
# This notebook runs multi-district MIP optimization experiments across three graph levels — **block group**, **tract**, and **block** — using both hierarchical distance metrics:
#
# | Metric | Edge weight | M |
# |---|---|---|
# | `hop_M` | 1 + {0, M, M²} | number of nodes |
# | `euclidean_M` | eucl(i,j) + {0, M, M²} | two-sweep diameter |
#
# The penalty tier is determined by GEOID20 prefix matching:
# - `GEOID20[:11]` match → same tract (no penalty)
# - `GEOID20[:5]` match → same county, different tract (+M)
# - Otherwise → different county (+M²)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

ROOT_DIR = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT_DIR))

import os
import pandas as pd
import matplotlib.pyplot as plt

from src.read import read_graph_from_json
from src.utils import get_roots
from src.experiment import run_optimization_experiment
from src.draw import visualize_roots

os.makedirs("../../results", exist_ok=True)
# Out:
# /Users/ishaanjolly/miniforge3/envs/tf_new2611/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Experiment parameters

# %%
GRAPH_LEVELS     = ["blockgroup", "block"]   
DISTANCE_METRICS = [None, "euclidean", "euclidean_M", "hop_M"]    

K = 4
DEVIATIONS = [50]
CONTIGUITY = ["tree", "dist", "dag", "cut"]
TIME_LIMIT = 3600

OBJECTIVES = ["hop_moi", "euclidean_moi", "weighted_moi", "cut_edges"]

total_combinations = len(GRAPH_LEVELS) * len(DISTANCE_METRICS)
print(f"Graph levels     : {GRAPH_LEVELS}")
print(f"Distance metrics : {DISTANCE_METRICS}")
print(f"Combinations     : {total_combinations}")
print(f"Experiments each : {len(DEVIATIONS) * len(CONTIGUITY)} × objectives")
# Out:
# Graph levels     : ['blockgroup', 'block']
# Distance metrics : [None, 'euclidean', 'euclidean_M', 'hop_M']
# Combinations     : 8
# Experiments each : 4 × objectives

# %% [markdown]
# ### Run all combinations

# %%
all_results = {}

for graph_level in GRAPH_LEVELS:
    print(f"Loading graph: IA_{graph_level}.json")
    G = read_graph_from_json(f"../../data/IA_{graph_level}.json", state="IA")
    has_coords = "X" in G.nodes[next(iter(G.nodes))]
    coord_key  = "coords" if has_coords else "no_coords"
    print(f"  {G.number_of_nodes()} nodes, {G.number_of_edges()} edges | coords: {has_coords}")

    for dist_metric in DISTANCE_METRICS:

        label = f"IA_{graph_level}_{dist_metric}"
        results_file = f"../../results/{label}_optimization.csv"

        df = run_optimization_experiment(
            G_base=G,
            deviations=DEVIATIONS,
            contiguity_models=CONTIGUITY,
            objectives=OBJECTIVES,
            k=K,
            distance_metric=dist_metric,
            time_limit=TIME_LIMIT,
            results_file=results_file,
        )

        df["graph_level"]     = graph_level
        df["distance_metric"] = dist_metric
        all_results[label]    = df

print(" All combinations complete.")
# Out:
# Loading graph: IA_blockgroup.json
#   2703 nodes, 7325 edges | coords: True
# Selected roots: [2375, 1533, 557, 1692]
# Distance metric: None
#
# Total experiments: 16
# Results will be saved to: ../../results/IA_blockgroup_None_optimization.csv
# ========================================================================
#
# [1/16] deviation=50 | contiguity=tree (dist: None) | objective_type=hop_moi
# Using L, U, k = 797543 797642 4
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-11-24
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 13519 rows, 10812 columns and 54036 nonzeros
# Model fingerprint: 0x2f9eee43
# Variable types: 0 continuous, 10812 integer (10812 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [4e+02, 4e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 6658 rows and 5638 columns
# Presolve time: 1.45s
# Presolved: 6861 rows, 5174 columns, 27262 nonzeros
# Variable types: 0 continuous, 5174 integer (5174 binary)
#
# Root relaxation: objective 5.847136e+08, 1364 iterations, 0.05 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5.8471e+08    0  123          - 5.8471e+08      -     -    1s
# H    0     0                    5.975197e+08 5.8471e+08  2.14%     -    1s
# H    0     0                    5.854137e+08 5.8471e+08  0.12%     -    1s
# H    0     0                    5.853956e+08 5.8471e+08  0.12%     -    1s
# H    0     0                    5.853534e+08 5.8471e+08  0.11%     -    1s
# H    0     0                    5.853517e+08 5.8471e+08  0.11%     -    1s
# H    0     0                    5.853211e+08 5.8471e+08  0.10%     -    1s
# H    0     0                    5.853169e+08 5.8471e+08  0.10%     -    1s
# H    0     0                    5.852970e+08 5.8471e+08  0.10%     -    1s
# H    0     0                    5.852968e+08 5.8471e+08  0.10%     -    1s
# H    0     0                    5.852559e+08 5.8471e+08  0.09%     -    1s
#      0     0 5.8519e+08    0  127 5.8526e+08 5.8519e+08  0.01%     -    1s
#      0     0 5.8519e+08    0    5 5.8526e+08 5.8519e+08  0.01%     -    1s
#      0     0 5.8519e+08    0   18 5.8526e+08 5.8519e+08  0.01%     -    1s
#      0     0 5.8519e+08    0   12 5.8526e+08 5.8519e+08  0.01%     -    1s
# H    0     0                    5.852541e+08 5.8519e+08  0.01%     -    1s
# H    0     0                    5.852400e+08 5.8519e+08  0.01%     -    1s
#      0     0 5.8519e+08    0    6 5.8524e+08 5.8519e+08  0.01%     -    1s
#      0     0 5.8519e+08    0    4 5.8524e+08 5.8519e+08  0.01%     -    2s
#      0     0 5.8520e+08    0    9 5.8524e+08 5.8520e+08  0.01%     -    2s
#      0     0 5.8520e+08    0    4 5.8524e+08 5.8520e+08  0.01%     -    2s
#      0     0 5.8520e+08    0    7 5.8524e+08 5.8520e+08  0.01%     -    2s
#      0     0 5.8520e+08    0   14 5.8524e+08 5.8520e+08  0.01%     -    2s
#      0     0 5.8520e+08    0   16 5.8524e+08 5.8520e+08  0.01%     -    2s
#      0     0 5.8521e+08    0   17 5.8524e+08 5.8521e+08  0.01%     -    2s
#      0     0 5.8521e+08    0   17 5.8524e+08 5.8521e+08  0.01%     -    2s
# H    0     0                    5.852258e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0    4 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   12 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   17 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   23 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   20 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   19 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   19 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   19 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   19 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     2 5.8521e+08    0   19 5.8523e+08 5.8521e+08  0.00%     -    2s
# H   57    77                    5.852206e+08 5.8521e+08  0.00%   5.4    2s
#
# Cutting planes:
#   Gomory: 1
#   Lift-and-project: 2
#   Cover: 7
#   MIR: 17
#   StrongCG: 7
#   GUB cover: 1
#   Inf proof: 15
#
# Explored 420 nodes (3526 simplex iterations) in 2.15 seconds (1.89 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 5.85221e+08
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.852205840000e+08, best bound 5.852205840000e+08, gap 0.0000%
#  Saved to ../../results/IA_blockgroup_None_optimization.csv
#
# [2/16] deviation=50 | contiguity=tree (dist: None) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 13519 rows, 10812 columns and 54036 nonzeros
# Model fingerprint: 0x24ba38e4
# Variable types: 0 continuous, 10812 integer (10812 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [2e+02, 1e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 6658 rows and 5638 columns
# Presolve time: 1.42s
# Presolved: 6861 rows, 5174 columns, 27262 nonzeros
# Variable types: 0 continuous, 5174 integer (5174 binary)
#
# Root relaxation: objective 9.215124e+10, 1276 iterations, 0.04 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9.2151e+10    0   16          - 9.2151e+10      -     -    1s
# H    0     0                    9.217226e+10 9.2151e+10  0.02%     -    1s
# H    0     0                    9.217141e+10 9.2151e+10  0.02%     -    1s
# H    0     0                    9.217061e+10 9.2151e+10  0.02%     -    1s
# H    0     0                    9.217050e+10 9.2151e+10  0.02%     -    1s
# H    0     0                    9.216506e+10 9.2151e+10  0.01%     -    1s
# H    0     0                    9.216247e+10 9.2151e+10  0.01%     -    1s
# H    0     0                    9.216198e+10 9.2151e+10  0.01%     -    1s
#      0     0 9.2154e+10    0   22 9.2162e+10 9.2154e+10  0.01%     -    1s
#      0     0 9.2154e+10    0    6 9.2162e+10 9.2154e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   13 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   10 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   14 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   15 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   14 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   21 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   21 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0    6 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   10 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   16 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   18 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   21 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   21 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   24 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   24 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2155e+10    0   24 9.2162e+10 9.2155e+10  0.01%     -    1s
#      0     0 9.2156e+10    0   26 9.2162e+10 9.2156e+10  0.01%     -    1s
#      0     0 9.2156e+10    0   26 9.2162e+10 9.2156e+10  0.01%     -    1s
#      0     2 9.2156e+10    0   26 9.2162e+10 9.2156e+10  0.01%     -    1s
# H   15    22                    9.216127e+10 9.2157e+10  0.00%  10.8    1s
# H   26    97                    9.215941e+10 9.2157e+10  0.00%   8.6    1s
#
# Cutting planes:
#   Gomory: 4
#   Lift-and-project: 2
#   Cover: 22
#   MIR: 12
#   StrongCG: 11
#   GUB cover: 2
#   Inf proof: 18
#   RLT: 5
#
# Explored 1016 nodes (5621 simplex iterations) in 1.85 seconds (1.76 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 9.21594e+10
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.215940846069e+10, best bound 9.215940846069e+10, gap 0.0000%
#  Saved to ../../results/IA_blockgroup_None_optimization.csv
#
# [3/16] deviation=50 | contiguity=tree (dist: None) | objective_type=weighted_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 13519 rows, 10812 columns and 54036 nonzeros
# Model fingerprint: 0x2f9eee43
# Variable types: 0 continuous, 10812 integer (10812 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [4e+02, 4e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 6658 rows and 5638 columns
# Presolve time: 1.46s
# Presolved: 6861 rows, 5174 columns, 27262 nonzeros
# Variable types: 0 continuous, 5174 integer (5174 binary)
#
# Root relaxation: objective 5.847136e+08, 1364 iterations, 0.05 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5.8471e+08    0  123          - 5.8471e+08      -     -    1s
# H    0     0                    5.975197e+08 5.8471e+08  2.14%     -    1s
# H    0     0                    5.854137e+08 5.8471e+08  0.12%     -    1s
# H    0     0                    5.853956e+08 5.8471e+08  0.12%     -    1s
# H    0     0                    5.853534e+08 5.8471e+08  0.11%     -    1s
# H    0     0                    5.853517e+08 5.8471e+08  0.11%     -    1s
# H    0     0                    5.853211e+08 5.8471e+08  0.10%     -    1s
# H    0     0                    5.853169e+08 5.8471e+08  0.10%     -    1s
# H    0     0                    5.852970e+08 5.8471e+08  0.10%     -    1s
# H    0     0                    5.852968e+08 5.8471e+08  0.10%     -    1s
# H    0     0                    5.852559e+08 5.8471e+08  0.09%     -    1s
#      0     0 5.8519e+08    0  127 5.8526e+08 5.8519e+08  0.01%     -    1s
#      0     0 5.8519e+08    0    5 5.8526e+08 5.8519e+08  0.01%     -    1s
#      0     0 5.8519e+08    0   18 5.8526e+08 5.8519e+08  0.01%     -    2s
#      0     0 5.8519e+08    0   12 5.8526e+08 5.8519e+08  0.01%     -    2s
# H    0     0                    5.852541e+08 5.8519e+08  0.01%     -    2s
# H    0     0                    5.852400e+08 5.8519e+08  0.01%     -    2s
#      0     0 5.8519e+08    0    6 5.8524e+08 5.8519e+08  0.01%     -    2s
#      0     0 5.8519e+08    0    4 5.8524e+08 5.8519e+08  0.01%     -    2s
#      0     0 5.8520e+08    0    9 5.8524e+08 5.8520e+08  0.01%     -    2s
#      0     0 5.8520e+08    0    4 5.8524e+08 5.8520e+08  0.01%     -    2s
#      0     0 5.8520e+08    0    7 5.8524e+08 5.8520e+08  0.01%     -    2s
#      0     0 5.8520e+08    0   14 5.8524e+08 5.8520e+08  0.01%     -    2s
#      0     0 5.8520e+08    0   16 5.8524e+08 5.8520e+08  0.01%     -    2s
#      0     0 5.8521e+08    0   17 5.8524e+08 5.8521e+08  0.01%     -    2s
#      0     0 5.8521e+08    0   17 5.8524e+08 5.8521e+08  0.01%     -    2s
# H    0     0                    5.852258e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0    4 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   12 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   17 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   23 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   20 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   19 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   19 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   19 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     0 5.8521e+08    0   19 5.8523e+08 5.8521e+08  0.00%     -    2s
#      0     2 5.8521e+08    0   19 5.8523e+08 5.8521e+08  0.00%     -    2s
# H   57    77                    5.852206e+08 5.8521e+08  0.00%   5.4    2s
#
# Cutting planes:
#   Gomory: 1
#   Lift-and-project: 2
#   Cover: 7
#   MIR: 17
#   StrongCG: 7
#   GUB cover: 1
#   Inf proof: 15
#
# Explored 420 nodes (3526 simplex iterations) in 2.14 seconds (1.89 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 5.85221e+08
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.852205840000e+08, best bound 5.852205840000e+08, gap 0.0000%
#  Saved to ../../results/IA_blockgroup_None_optimization.csv
#
# [4/16] deviation=50 | contiguity=tree (dist: None) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 86769 rows, 76737 columns and 303086 nonzeros
# Model fingerprint: 0x5f9691de
# Variable types: 0 continuous, 76737 integer (76737 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 12550 rows and 12521 columns
# Presolve time: 0.49s
# Presolved: 74219 rows, 64216 columns, 256152 nonzeros
# Variable types: 0 continuous, 64216 integer (64216 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   108321    3.6029767e+02   7.850498e+01   3.530850e+08      5s
#   130390    2.0952767e+02   0.000000e+00   9.736357e+03     10s
#   140815    1.5525080e+02   0.000000e+00   1.114318e+05     15s
#   149333    1.2756543e+02   0.000000e+00   7.640443e+04     20s
#   156263    1.2366604e+02   0.000000e+00   3.200123e+04     25s
#   163713    1.0578189e+02   0.000000e+00   2.782465e+04     30s
#   170971    9.2313825e+01   0.000000e+00   3.862733e+04     35s
#   177559    8.9582351e+01   0.000000e+00   5.713753e+04     40s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    54800    8.9998830e+00   0.000000e+00   0.000000e+00     44s
#
# Root relaxation: objective 8.999883e+00, 54800 iterations, 43.83 seconds (51.52 work units)
# Total elapsed time = 45.01s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    8.99988    0 10757          -    8.99988      -     -   58s
#      0     0   91.63661    0 7250          -   91.63661      -     -  140s
# H    0     0                     356.0000000   91.63661  74.3%     -  140s
#      0     0   92.55675    0 8222  356.00000   92.55675  74.0%     -  143s
#      0     0   92.55675    0 5380  356.00000   92.55675  74.0%     -  172s
# H    0     0                     350.0000000   92.55675  73.6%     -  172s
# H    0     0                     315.0000000   92.55728  70.6%     -  174s
# H    0     0                     310.0000000   92.55728  70.1%     -  174s
# H    0     0                     289.0000000   92.55728  68.0%     -  174s
#      0     0   92.62059    0 4687  289.00000   92.62059  68.0%     -  176s
#      0     0   92.63649    0 4731  289.00000   92.63649  67.9%     -  180s
#      0     0   92.71648    0 4505  289.00000   92.71648  67.9%     -  183s
#      0     0   92.71878    0 4505  289.00000   92.71878  67.9%     -  185s
#      0     2   92.72529    0 4505  289.00000   92.72529  67.9%     -  186s
#      1     3  103.57203    1 2764  289.00000   92.72529  67.9% 13689  193s
#      2     6  136.93399    2 1575  289.00000   92.72529  67.9% 10340  200s
#      5    10 infeasible    3       289.00000  107.12790  62.9%  7128  206s
#     19    40  120.16062    5 2148  289.00000  112.00585  61.2%  4643  212s
#     41    67  131.88417    6 2075  289.00000  112.00585  61.2%  4711  215s
# H   42    67                     288.0000000  112.00585  61.1%  4599  215s
# H   96   119                     287.0000000  112.00585  61.0%  2449  218s
# H  117   119                     187.0000000  112.00585  40.1%  2095  218s
# H  122   145                     184.0000000  112.00585  39.1%  2029  218s
#    188   191  149.13978   12  644  184.00000  112.00585  39.1%  1405  220s
# H  427   419                     169.0000000  115.86055  31.4%   731  224s
#    453   428  158.27734   25  273  169.00000  115.86055  31.4%   694  226s
# H  504   436                     163.0000000  117.93241  27.6%   651  227s
# H  514   436                     161.0000000  117.93241  26.8%   645  227s
#    570   440  123.44394    7  930  161.00000  122.73725  23.8%   644  231s
# H  572   440                     155.0000000  122.73725  20.8%   644  231s
#    620   447  124.64960    9  829  155.00000  122.73725  20.8%   638  235s
# H  621   447                     142.0000000  122.73725  13.6%   637  235s
# H  625   447                     141.0000000  122.73725  13.0%   634  235s
# H  686   464                     138.0000000  122.73725  11.1%   635  238s
# H  773   457                     136.0000000  122.73725  9.75%   596  240s
# H  886   443                     135.0000000  123.45447  8.55%   564  243s
#   1013   445  132.87329   16  714  135.00000  126.24859  6.48%   534  245s
# H 1149   429                     134.0000000  127.63185  4.75%   500  246s
# H 1264   478                     133.0000000  128.25112  3.57%   477  248s
#   1544   287  129.20908   28  104  133.00000  129.01663  3.00%   413  250s
#   2555     0  131.21421   30   32  133.00000  131.00000  1.50%   287  255s
#
# Cutting planes:
#   Cover: 26
#   Clique: 31
#   Inf proof: 3
#   Zero half: 13
#   Relax-and-lift: 2
#
# Explored 2629 nodes (1011337 simplex iterations) in 255.69 seconds (338.59 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 133
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 1.330000000000e+02, best bound 1.330000000000e+02, gap 0.0000%
#  Saved to ../../results/IA_blockgroup_None_optimization.csv
#
# [5/16] deviation=50 | contiguity=dist (dist: None) | objective_type=hop_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 13519 rows, 10812 columns and 61424 nonzeros
# Model fingerprint: 0x692ca1f8
# Variable types: 0 continuous, 10812 integer (10812 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [4e+02, 4e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 3282 rows and 2825 columns
# Presolve time: 0.92s
# Presolved: 10237 rows, 7987 columns, 45909 nonzeros
# Variable types: 0 continuous, 7987 integer (7987 binary)
#
# Root relaxation: objective 5.843482e+08, 2326 iterations, 0.09 seconds (0.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5.8435e+08    0  202          - 5.8435e+08      -     -    1s
# H    0     0                    5.870063e+08 5.8435e+08  0.45%     -    1s
# H    0     0                    5.869964e+08 5.8435e+08  0.45%     -    1s
# H    0     0                    5.869019e+08 5.8435e+08  0.44%     -    1s
# H    0     0                    5.848410e+08 5.8435e+08  0.08%     -    1s
# H    0     0                    5.848363e+08 5.8435e+08  0.08%     -    1s
# H    0     0                    5.848169e+08 5.8435e+08  0.08%     -    1s
# H    0     0                    5.848162e+08 5.8435e+08  0.08%     -    1s
#      0     0 5.8468e+08    0  119 5.8482e+08 5.8468e+08  0.02%     -    1s
#      0     0 5.8468e+08    0   44 5.8482e+08 5.8468e+08  0.02%     -    1s
#      0     0 5.8476e+08    0   67 5.8482e+08 5.8476e+08  0.01%     -    1s
#      0     0 5.8476e+08    0   75 5.8482e+08 5.8476e+08  0.01%     -    1s
#      0     0 5.8476e+08    0   65 5.8482e+08 5.8476e+08  0.01%     -    1s
#      0     0 5.8477e+08    0   91 5.8482e+08 5.8477e+08  0.01%     -    1s
#      0     0 5.8477e+08    0   33 5.8482e+08 5.8477e+08  0.01%     -    1s
# H    0     0                    5.848041e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   66 5.8480e+08 5.8478e+08  0.00%     -    1s
# H    0     0                    5.848033e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   61 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   64 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   59 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   22 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0    8 5.8480e+08 5.8478e+08  0.00%     -    1s
# H    0     0                    5.848000e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   15 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   37 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   36 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   36 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   36 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   21 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0    4 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   35 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   35 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   35 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   42 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   45 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   38 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   36 5.8480e+08 5.8478e+08  0.00%     -    1s
# H    0     0                    5.847968e+08 5.8478e+08  0.00%     -    1s
# H    0     0                    5.847961e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   15 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0    3 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   20 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   16 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   29 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   29 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0    9 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   11 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   15 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   17 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   19 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   20 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   29 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   29 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     2 5.8478e+08    0   29 5.8480e+08 5.8478e+08  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 5
#   Cover: 41
#   MIR: 10
#   StrongCG: 4
#   GUB cover: 2
#   Inf proof: 10
#   RLT: 3
#
# Explored 4119 nodes (21501 simplex iterations) in 1.88 seconds (1.62 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 5.84796e+08
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.847961180000e+08, best bound 5.847961180000e+08, gap 0.0000%
#  Saved to ../../results/IA_blockgroup_None_optimization.csv
#
# [6/16] deviation=50 | contiguity=dist (dist: None) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 13519 rows, 10812 columns and 61424 nonzeros
# Model fingerprint: 0xef917851
# Variable types: 0 continuous, 10812 integer (10812 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [2e+02, 1e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 3282 rows and 2825 columns
# Presolve time: 0.93s
# Presolved: 10237 rows, 7987 columns, 45909 nonzeros
# Variable types: 0 continuous, 7987 integer (7987 binary)
#
# Root relaxation: objective 9.211731e+10, 2070 iterations, 0.08 seconds (0.24 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9.2117e+10    0   57          - 9.2117e+10      -     -    1s
# H    0     0                    9.213336e+10 9.2117e+10  0.02%     -    1s
# H    0     0                    9.213287e+10 9.2117e+10  0.02%     -    1s
# H    0     0                    9.213217e+10 9.2117e+10  0.02%     -    1s
# H    0     0                    9.213188e+10 9.2117e+10  0.02%     -    1s
# H    0     0                    9.213083e+10 9.2117e+10  0.01%     -    1s
# H    0     0                    9.212949e+10 9.2117e+10  0.01%     -    1s
# H    0     0                    9.212508e+10 9.2119e+10  0.01%     -    1s
#      0     0 9.2120e+10    0   10 9.2125e+10 9.2120e+10  0.01%     -    1s
#      0     0 9.2120e+10    0    3 9.2125e+10 9.2120e+10  0.01%     -    1s
# H    0     0                    9.212459e+10 9.2120e+10  0.01%     -    1s
# H    0     0                    9.212410e+10 9.2120e+10  0.00%     -    1s
#      0     0 9.2120e+10    0    9 9.2124e+10 9.2120e+10  0.00%     -    1s
#      0     0 9.2120e+10    0    4 9.2124e+10 9.2120e+10  0.00%     -    1s
#      0     0 9.2120e+10    0   10 9.2124e+10 9.2120e+10  0.00%     -    1s
#      0     0 9.2120e+10    0   10 9.2124e+10 9.2120e+10  0.00%     -    1s
#      0     0 9.2121e+10    0   13 9.2124e+10 9.2121e+10  0.00%     -    1s
#      0     0 9.2121e+10    0   13 9.2124e+10 9.2121e+10  0.00%     -    1s
#      0     0 9.2121e+10    0   14 9.2124e+10 9.2121e+10  0.00%     -    1s
#      0     0 9.2121e+10    0   17 9.2124e+10 9.2121e+10  0.00%     -    1s
#      0     0 9.2121e+10    0   17 9.2124e+10 9.2121e+10  0.00%     -    1s
#      0     2 9.2121e+10    0   17 9.2124e+10 9.2121e+10  0.00%     -    1s
# H  104    97                    9.212404e+10 9.2122e+10  0.00%   6.1    1s
# H  309   172                    9.212370e+10 9.2122e+10  0.00%   4.1    1s
#
# Cutting planes:
#   Gomory: 6
#   Cover: 14
#   MIR: 26
#   StrongCG: 12
#   GUB cover: 1
#   Inf proof: 21
#
# Explored 1288 nodes (7329 simplex iterations) in 1.41 seconds (1.32 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 9.21237e+10
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.212369804774e+10, best bound 9.212369804774e+10, gap 0.0000%
#  Saved to ../../results/IA_blockgroup_None_optimization.csv
#
# [7/16] deviation=50 | contiguity=dist (dist: None) | objective_type=weighted_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 13519 rows, 10812 columns and 61424 nonzeros
# Model fingerprint: 0x692ca1f8
# Variable types: 0 continuous, 10812 integer (10812 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [4e+02, 4e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 3282 rows and 2825 columns
# Presolve time: 0.92s
# Presolved: 10237 rows, 7987 columns, 45909 nonzeros
# Variable types: 0 continuous, 7987 integer (7987 binary)
#
# Root relaxation: objective 5.843482e+08, 2326 iterations, 0.09 seconds (0.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5.8435e+08    0  202          - 5.8435e+08      -     -    1s
# H    0     0                    5.870063e+08 5.8435e+08  0.45%     -    1s
# H    0     0                    5.869964e+08 5.8435e+08  0.45%     -    1s
# H    0     0                    5.869019e+08 5.8435e+08  0.44%     -    1s
# H    0     0                    5.848410e+08 5.8435e+08  0.08%     -    1s
# H    0     0                    5.848363e+08 5.8435e+08  0.08%     -    1s
# H    0     0                    5.848169e+08 5.8435e+08  0.08%     -    1s
# H    0     0                    5.848162e+08 5.8435e+08  0.08%     -    1s
#      0     0 5.8468e+08    0  119 5.8482e+08 5.8468e+08  0.02%     -    1s
#      0     0 5.8468e+08    0   44 5.8482e+08 5.8468e+08  0.02%     -    1s
#      0     0 5.8476e+08    0   67 5.8482e+08 5.8476e+08  0.01%     -    1s
#      0     0 5.8476e+08    0   75 5.8482e+08 5.8476e+08  0.01%     -    1s
#      0     0 5.8476e+08    0   65 5.8482e+08 5.8476e+08  0.01%     -    1s
#      0     0 5.8477e+08    0   91 5.8482e+08 5.8477e+08  0.01%     -    1s
#      0     0 5.8477e+08    0   33 5.8482e+08 5.8477e+08  0.01%     -    1s
# H    0     0                    5.848041e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   66 5.8480e+08 5.8478e+08  0.00%     -    1s
# H    0     0                    5.848033e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   61 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   64 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   59 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   22 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0    8 5.8480e+08 5.8478e+08  0.00%     -    1s
# H    0     0                    5.848000e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   15 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   37 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   36 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   36 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   36 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   21 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0    4 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   35 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   35 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   35 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   42 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   45 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   38 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   36 5.8480e+08 5.8478e+08  0.00%     -    1s
# H    0     0                    5.847968e+08 5.8478e+08  0.00%     -    1s
# H    0     0                    5.847961e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   15 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0    3 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   20 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   16 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   29 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   29 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0    9 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   11 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   15 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   17 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   19 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   20 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   29 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     0 5.8478e+08    0   29 5.8480e+08 5.8478e+08  0.00%     -    1s
#      0     2 5.8478e+08    0   29 5.8480e+08 5.8478e+08  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 5
#   Cover: 41
#   MIR: 10
#   StrongCG: 4
#   GUB cover: 2
#   Inf proof: 10
#   RLT: 3
#
# Explored 4119 nodes (21501 simplex iterations) in 1.90 seconds (1.62 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 5.84796e+08
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 5.847961180000e+08, best bound 5.847961180000e+08, gap 0.0000%
#  Saved to ../../results/IA_blockgroup_None_optimization.csv
#
#
#    369   368  126.80217   32  627          -   71.57084      -  2283 3157s
#    415   430  128.55289   34  768          -   71.57084      -  2146 3166s
#    483   511  129.78181   37  235          -   71.57084      -  1947 3180s
# H  491   511                     207.0000000   71.57084  65.4%  1925 3180s
# H  572   598                     174.0000000   71.57084  58.9%  1706 3184s
#    689   655  149.90644   57   70  174.00000   71.57084  58.9%  1458 3200s
# H  755   564                     163.0000000   71.57084  56.1%  1348 3200s
#    802   615  152.85588   75  154  163.00000   71.57084  56.1%  1283 3217s
# H  891   690                     162.0000000   73.16766  54.8%  1179 3230s
#   1012   742     cutoff  110       162.00000   73.16766  54.8%  1064 3246s
#   1104   801  145.96052   67  103  162.00000   73.16766  54.8%   993 3264s
# H 1156   483                     146.0000000   73.16766  49.9%   958 3264s
#   1217   413     cutoff   92       146.00000   73.16766  49.9%   926 3285s
#   1240   419  127.88630   12 3711  146.00000   73.16766  49.9%   929 3302s
# H 1245   419                     144.0000000   73.16766  49.2%   941 3302s
#   1255   425     cutoff   14       144.00000   73.16766  49.2%   952 3319s
#   1290   422     cutoff   15       144.00000   73.16766  49.2%   959 3342s
# H 1295   422                     143.0000000   73.16766  48.8%   968 3342s
#   1311   451  126.95175   19  475  143.00000   73.16766  48.8%   967 3359s
# H 1356   513                     141.0000000   73.16766  48.1%   968 4348s
#
# Cutting planes:
#   Cover: 1
#   Clique: 22
#   Zero half: 28
#
# Explored 1480 nodes (1854455 simplex iterations) in 4348.11 seconds (1841.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 141
#
# Time limit reached
# Best objective 1.410000000000e+02, best bound 7.400000000000e+01, gap 47.5177%
#  Saved to ../../results/IA_blockgroup_None_optimization.csv
#
# [9/16] deviation=50 | contiguity=dag (dist: None) | objective_type=hop_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 13519 rows, 10812 columns and 72528 nonzeros
# Model fingerprint: 0x70065666
# Variable types: 0 continuous, 10812 integer (10812 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [4e+02, 4e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 986 rows and 778 columns
# Presolve time: 0.30s
# Presolved: 12533 rows, 10034 columns, 64099 nonzeros
# Variable types: 0 continuous, 10034 integer (10034 binary)
#
# Root relaxation: objective 5.837498e+08, 2574 iterations, 0.16 seconds (0.41 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5.8375e+08    0  154          - 5.8375e+08      -     -    0s
# H    0     0                    5.847003e+08 5.8375e+08  0.16%     -    1s
# H    0     0                    5.844325e+08 5.8375e+08  0.12%     -    1s
# H    0     0                    5.844309e+08 5.8375e+08  0.12%     -    1s
# H    0     0                    5.843763e+08 5.8375e+08  0.11%     -    1s
# H    0     0                    5.843702e+08 5.8375e+08  0.11%     -    1s
# H    0     0                    5.843220e+08 5.8375e+08  0.10%     -    1s
#      0     0 5.8387e+08    0  156 5.8432e+08 5.8387e+08  0.08%     -    1s
#      0     0 5.8387e+08    0   54 5.8432e+08 5.8387e+08  0.08%     -    1s
# H    0     0                    5.843129e+08 5.8387e+08  0.08%     -    1s
# H    0     0                    5.842997e+08 5.8387e+08  0.07%     -    1s
# H    0     0                    5.842989e+08 5.8387e+08  0.07%     -    1s

# H    0     0                    3.531451e+10 3.5314e+10  0.00%     -  312s
#      0     0 3.5314e+10    0   36 3.5315e+10 3.5314e+10  0.00%     -  312s
#      0     0 3.5314e+10    0   45 3.5315e+10 3.5314e+10  0.00%     -  312s
# H    0     0                    3.531451e+10 3.5314e+10  0.00%     -  312s
#      0     0 3.5314e+10    0   36 3.5315e+10 3.5314e+10  0.00%     -  312s
#      0     0 3.5314e+10    0   52 3.5315e+10 3.5314e+10  0.00%     -  313s
#      0     0 3.5314e+10    0   52 3.5315e+10 3.5314e+10  0.00%     -  313s
# H    0     0                    3.531451e+10 3.5314e+10  0.00%     -  313s
# H    0     0                    3.531451e+10 3.5314e+10  0.00%     -  313s
# H    0     0                    3.531451e+10 3.5314e+10  0.00%     -  313s
# H    0     0                    3.531451e+10 3.5314e+10  0.00%     -  313s
#      0     2 3.5314e+10    0   52 3.5315e+10 3.5314e+10  0.00%     -  313s
# H   69   178                    3.531451e+10 3.5315e+10  0.00%   4.9  313s
# H   69   178                    3.531451e+10 3.5315e+10  0.00%   4.9  313s
# H  173   178                    3.531451e+10 3.5315e+10  0.00%   3.0  313s
# *  197   231              36    3.531451e+10 3.5315e+10  0.00%   2.9  313s
# *  236   231              14    3.531451e+10 3.5315e+10  0.00%   2.8  313s
# *  293   231              31    3.531451e+10 3.5315e+10  0.00%   2.6  313s
# H  309   231                    3.531451e+10 3.5315e+10  0.00%   2.5  313s
#
# Cutting planes:
#   Gomory: 4
#   Lift-and-project: 4
#   Implied bound: 1
#   Clique: 5
#   MIR: 7
#   StrongCG: 1
#   RLT: 5
#
# Explored 733 nodes (312536 simplex iterations) in 313.97 seconds (187.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 3.53145e+10
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 3.531451229600e+10, best bound 3.531451229600e+10, gap 0.0000%
#  Saved to ../../results/IA_block_None_optimization.csv
#
# [8/16] deviation=50 | contiguity=dist (dist: None) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 5041259 rows, 4449530 columns and 17669023 nonzeros
# Model fingerprint: 0x0bbb9160
# Variable types: 0 continuous, 4449530 integer (4449530 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 85 rows and 73 columns (presolve time = 5s)...
# Presolve removed 386696 rows and 122 columns (presolve time = 10s)...
# Presolve removed 406366 rows and 386684 columns (presolve time = 15s)...
# Presolve removed 410012 rows and 410000 columns (presolve time = 20s)...
# Presolve removed 424730 rows and 424706 columns (presolve time = 25s)...
# Presolve removed 424730 rows and 424706 columns (presolve time = 30s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 35s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 40s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 45s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 50s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 60s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 65s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 70s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 75s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 80s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 85s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 90s)...
# Presolve removed 424742 rows and 424718 columns (presolve time = 95s)...
# Presolve removed 448759 rows and 448645 columns (presolve time = 101s)...
# Presolve removed 449108 rows and 448993 columns (presolve time = 105s)...
# Presolve removed 450790 rows and 449142 columns (presolve time = 110s)...
# Presolve removed 451884 rows and 451631 columns (presolve time = 115s)...
# Presolve removed 451899 rows and 451646 columns (presolve time = 120s)...
# Presolve removed 451899 rows and 451646 columns (presolve time = 125s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 135s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 140s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 145s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 150s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 155s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 160s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 165s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 170s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 175s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 180s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 185s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 190s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 195s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 200s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 205s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 210s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 215s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 220s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 225s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 230s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 235s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 240s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 245s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 250s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 255s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 260s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 265s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 270s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 275s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 280s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 285s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 290s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 295s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 300s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 305s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 310s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 315s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 320s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 325s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 330s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 335s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 340s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 345s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 350s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 355s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 360s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 365s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 370s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 375s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 380s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 385s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 390s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 395s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 400s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 405s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 410s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 415s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 420s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 425s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 430s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 435s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 440s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 445s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 450s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 455s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 460s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 465s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 470s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 475s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 480s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 485s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 490s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 495s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 500s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 505s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 510s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 515s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 520s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 525s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 530s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 535s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 540s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 545s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 550s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 555s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 560s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 565s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 570s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 575s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 580s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 585s)...
# Presolve removed 452086 rows and 451653 columns (presolve time = 627s)...
# Presolve removed 525155 rows and 525203 columns (presolve time = 631s)...
# Presolve removed 530413 rows and 530012 columns (presolve time = 635s)...
# Presolve removed 534211 rows and 533071 columns (presolve time = 640s)...
# Presolve removed 535356 rows and 533213 columns (presolve time = 645s)...
# Presolve removed 535454 rows and 534296 columns
# Presolve time: 649.12s
# Presolved: 4505805 rows, 3915234 columns, 15601694 nonzeros
# Variable types: 0 continuous, 3915234 integer (3915234 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Elapsed ordering time = 9s
# Elapsed ordering time = 10s
# Elapsed ordering time = 15s
# Elapsed ordering time = 38s
# Elapsed ordering time = 40s
# Elapsed ordering time = 45s
# Elapsed ordering time = 50s
# Ordering time: 162.37s
# Elapsed ordering time = 172s
# Elapsed ordering time = 175s
# Elapsed ordering time = 180s
# Elapsed ordering time = 208s
# Elapsed ordering time = 216s
# Elapsed ordering time = 223s
# Elapsed ordering time = 227s
# Elapsed ordering time = 231s
# Elapsed ordering time = 238s
# Elapsed ordering time = 241s
# Elapsed ordering time = 245s
# Elapsed ordering time = 251s
# Elapsed ordering time = 256s
# Elapsed ordering time = 260s
# Elapsed ordering time = 265s
# Elapsed ordering time = 271s
# Elapsed ordering time = 275s
# Elapsed ordering time = 281s
# Elapsed ordering time = 285s
# Elapsed ordering time = 290s
# Elapsed ordering time = 295s
# Elapsed ordering time = 300s
# Elapsed ordering time = 305s
# Elapsed ordering time = 310s
# Elapsed ordering time = 315s
# Elapsed ordering time = 320s
# Elapsed ordering time = 345s
# Elapsed ordering time = 353s
# Elapsed ordering time = 359s
# Elapsed ordering time = 363s
# Elapsed ordering time = 365s
# Elapsed ordering time = 372s
# Elapsed ordering time = 376s
# Elapsed ordering time = 380s
# Elapsed ordering time = 385s
# Elapsed ordering time = 390s
# Elapsed ordering time = 395s
# Elapsed ordering time = 400s
# Elapsed ordering time = 405s
# Elapsed ordering time = 410s
# Elapsed ordering time = 418s
# Elapsed ordering time = 420s
# Elapsed ordering time = 425s
# Elapsed ordering time = 430s
# Elapsed ordering time = 435s
# Elapsed ordering time = 440s
# Elapsed ordering time = 445s
# Elapsed ordering time = 450s
# Elapsed ordering time = 455s
# Elapsed ordering time = 460s
# Elapsed ordering time = 465s
# Elapsed ordering time = 470s
# Elapsed ordering time = 475s
# Elapsed ordering time = 480s
# Elapsed ordering time = 485s
# Elapsed ordering time = 490s
# Ordering time: 497.92s
#
# Barrier statistics:
#  Dense cols : 869
#  AA' NZ     : 5.630e+07
#  Factor NZ  : 1.196e+09 (roughly 13.0 GB of memory)
#  Factor Ops : 1.040e+12 (roughly 5 seconds per iteration)
#  Threads    : 5
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
