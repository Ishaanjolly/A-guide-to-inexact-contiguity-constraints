# %% [markdown]
# ## Iowa Optimization — Hierarchical M Experiments (Block Group, Tract, Block)
#
# This notebook runs multi-district MIP optimization experiments across three graph levels — **block group**, **tract**, and **block** — using both hierarchical distance metrics:
#
# | Metric | Edge weight | M |
# |---|---|---|
# | `hop_M` | 1 + {0, M, M²} | number of nodes |
# | `euclidean_M` | eucl(i,j) + {0, M, M²} | two-sweep diameter |
#
# The penalty tier is determined by GEOID20 prefix matching:
# - `GEOID20[:11]` match → same tract (no penalty)
# - `GEOID20[:5]` match → same county, different tract (+M)
# - Otherwise → different county (+M²)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

ROOT_DIR = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT_DIR))

import os
import pandas as pd
import matplotlib.pyplot as plt

from src.read import read_graph_from_json
from src.utils import get_roots
from src.experiment import run_optimization_experiment
from src.draw import visualize_roots

os.makedirs("../../results", exist_ok=True)

# %% [markdown]
# ### Experiment parameters

# %%
GRAPH_LEVELS     = ["county"]   
DISTANCE_METRICS = ["hop"]    

K = 4
DEVIATIONS = [50]
CONTIGUITY = ["tree", "dist", "dag", "cut"]
TIME_LIMIT = 3600

OBJECTIVES = ["hop_moi", "euclidean_moi", "weighted_moi", "cut_edges"]

total_combinations = len(GRAPH_LEVELS) * len(DISTANCE_METRICS)
print(f"Graph levels     : {GRAPH_LEVELS}")
print(f"Distance metrics : {DISTANCE_METRICS}")
print(f"Combinations     : {total_combinations}")
print(f"Experiments each : {len(DEVIATIONS) * len(CONTIGUITY)} × objectives")
# Out:
# Graph levels     : ['county']
# Distance metrics : ['hop']
# Combinations     : 1
# Experiments each : 4 × objectives

# %% [markdown]
# ### Run all combinations

# %%
all_results = {}

for graph_level in GRAPH_LEVELS:
    print(f"Loading graph: IA_{graph_level}.json")
    G = read_graph_from_json(f"../../data/IA_{graph_level}.json", state="IA")
    has_coords = "X" in G.nodes[next(iter(G.nodes))]
    coord_key  = "coords" if has_coords else "no_coords"
    print(f"  {G.number_of_nodes()} nodes, {G.number_of_edges()} edges | coords: {has_coords}")

    for dist_metric in DISTANCE_METRICS:

        label = f"IA_{graph_level}_{dist_metric}"
        results_file = f"../../results/{label}_optimization.csv"

        df = run_optimization_experiment(
            G_base=G,
            deviations=DEVIATIONS,
            contiguity_models=CONTIGUITY,
            objectives=OBJECTIVES,
            k=K,
            distance_metric=dist_metric,
            time_limit=TIME_LIMIT,
            results_file=results_file,
        )

        df["graph_level"]     = graph_level
        df["distance_metric"] = dist_metric
        all_results[label]    = df

print(" All combinations complete.")
# Out:
# Loading graph: IA_county.json
#   99 nodes, 222 edges | coords: True
# Selected roots: [56, 26, 40, 27]
# Distance metric: hop
#
# Total experiments: 16
# Results will be saved to: ../../results/IA_county_hop_optimization.csv
# ========================================================================
#
# [1/16] deviation=50 | contiguity=tree (dist: hop) | objective_type=hop_moi
# Using L, U, k = 797543 797642 4
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-11-24
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 499 rows, 396 columns and 1972 nonzeros
# Model fingerprint: 0x1a9d92c9
# Variable types: 0 continuous, 396 integer (396 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+05]
#   Objective range  [6e+03, 3e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 316 rows and 249 columns
# Presolve time: 0.01s
# Presolved: 183 rows, 147 columns, 793 nonzeros
# Variable types: 0 continuous, 147 integer (147 binary)
#
# Root relaxation: objective 7.088991e+07, 35 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7.0890e+07    0    7          - 7.0890e+07      -     -    0s
#      0     0 7.2241e+07    0   10          - 7.2241e+07      -     -    0s
#      0     0 7.2249e+07    0   10          - 7.2249e+07      -     -    0s
#      0     0 7.2343e+07    0   13          - 7.2343e+07      -     -    0s
#      0     0 7.2391e+07    0   13          - 7.2391e+07      -     -    0s
#      0     0 7.2453e+07    0   21          - 7.2453e+07      -     -    0s
#      0     0 7.2486e+07    0   23          - 7.2486e+07      -     -    0s
#      0     0 7.2496e+07    0   20          - 7.2496e+07      -     -    0s
#      0     0 7.2499e+07    0   37          - 7.2499e+07      -     -    0s
#      0     0 7.2502e+07    0   19          - 7.2502e+07      -     -    0s
#      0     0 7.2541e+07    0   25          - 7.2541e+07      -     -    0s
#      0     0 7.2564e+07    0   25          - 7.2564e+07      -     -    0s
#      0     0 7.2581e+07    0   30          - 7.2581e+07      -     -    0s
#      0     0 7.2586e+07    0   27          - 7.2586e+07      -     -    0s
#      0     0 7.2586e+07    0   27          - 7.2586e+07      -     -    0s
#      0     0 7.2661e+07    0   32          - 7.2661e+07      -     -    0s
#      0     0 7.2661e+07    0   32          - 7.2661e+07      -     -    0s
#      0     0 7.2674e+07    0   34          - 7.2674e+07      -     -    0s
#      0     0 7.2688e+07    0   38          - 7.2688e+07      -     -    0s
#      0     0 7.2690e+07    0   38          - 7.2690e+07      -     -    0s
#      0     0 7.2694e+07    0   38          - 7.2694e+07      -     -    0s
#      0     0 7.2698e+07    0   39          - 7.2698e+07      -     -    0s
#      0     0 7.2699e+07    0   38          - 7.2699e+07      -     -    0s
#      0     0 7.2699e+07    0   38          - 7.2699e+07      -     -    0s
#      0     0 7.2702e+07    0   31          - 7.2702e+07      -     -    0s
#      0     0 7.2705e+07    0   43          - 7.2705e+07      -     -    0s
#      0     0 7.2713e+07    0   33          - 7.2713e+07      -     -    0s
#      0     0 7.2713e+07    0   33          - 7.2713e+07      -     -    0s
#      0     2 7.2714e+07    0   33          - 7.2714e+07      -     -    0s
#
# Explored 29320 nodes (122463 simplex iterations) in 0.79 seconds (0.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#  Saved to ../../results/IA_county_hop_optimization.csv
#
# [2/16] deviation=50 | contiguity=tree (dist: hop) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 499 rows, 396 columns and 1972 nonzeros
# Model fingerprint: 0xea2c5e4d
# Variable types: 0 continuous, 396 integer (396 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+05]
#   Objective range  [1e+07, 4e+10]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 316 rows and 249 columns
# Presolve time: 0.01s
# Presolved: 183 rows, 147 columns, 793 nonzeros
# Variable types: 0 continuous, 147 integer (147 binary)
#
# Root relaxation: objective 7.639276e+10, 32 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7
moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 499 rows, 396 columns and 1972 nonzeros
# Model fingerprint: 0x1a9d92c9
# Variable types: 0 continuous, 396 integer (396 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+05]
#   Objective range  [6e+03, 3e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 316 rows and 249 columns
# Presolve time: 0.01s
# Presolved: 183 rows, 147 columns, 793 nonzeros
# Variable types: 0 continuous, 147 integer (147 binary)
#
# Root relaxation: objective 7.088991e+07, 35 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7.0890e+07    0    7          - 7.0890e+07      -     -    0s
#      0     0 7.2241e+07    0   10          - 7.2241e+07      -     -    0s
#      0     0 7.2249e+07    0   10          - 7.2249e+07      -     -    0s
#      0     0 7.2343e+07    0   13          - 7.2343e+07      -     -    0s
#      0     0 7.2391e+07    0   13          - 7.2391e+07      -     -    0s
#      0     0 7.2453e+07    0   21          - 7.2453e+07      -     -    0s
#      0     0 7.2486e+07    0   23          - 7.2486e+07      -     -    0s
#      0     0 7.2496e+07    0   20          - 7.2496e+07      -     -    0s
#      0     0 7.2499e+07    0   37          - 7.2499e+07      -     -    0s
#      0     0 7.2502e+07    0   19          - 7.2502e+07      -     -    0s
#      0     0 7.2541e+07    0   25          - 7.2541e+07      -     -    0s
#      0     0 7.2564e+07    0   25          - 7.2564e+07      -     -    0s
#      0     0 7.2581e+07    0   30          - 7.2581e+07      -     -    0s
#      0     0 7.2586e+07    0   27          - 7.2586e+07      -     -    0s
#      0     0 7.2586e+07    0   27          - 7.2586e+07      -     -    0s
#      0     0 7.2661e+07    0   32          - 7.2661e+07      -     -    0s
#      0     0 7.2661e+07    0   32          - 7.2661e+07      -     -    0s
#      0     0 7.2674e+07    0   34          - 7.2674e+07      -     -    0s
#      0     0 7.2688e+07    0   38          - 7.2688e+07      -     -    0s
#      0     0 7.2690e+07    0   38          - 7.2690e+07      -     -    0s
#      0     0 7.2694e+07    0   38          - 7.2694e+07      -     -    0s
#      0     0 7.2698e+07    0   39          - 7.2698e+07      -     -    0s
#      0     0 7.2699e+07    0   38          - 7.2699e+07      -     -    0s
#      0     0 7.2699e+07    0   38          - 7.2699e+07      -     -    0s
#      0     0 7.2702e+07    0   31          - 7.2702e+07      -     -    0s
#      0     0 7.2705e+07    0   43          - 7.2705e+07      -     -    0s
#      0     0 7.2713e+07    0   33          - 7.2713e+07      -     -    0s
#      0     0 7.2713e+07    0   33          - 7.2713e+07      -     -    0s
#      0     2 7.2714e+07    0   33          - 7.2714e+07      -     -    0s
#
# Explored 29320 nodes (122463 simplex iterations) in 0.77 seconds (0.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#  Saved to ../../results/IA_county_hop_optimization.csv
#
# [4/16] deviation=50 | contiguity=tree (dist: hop) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 2719 rows, 2394 columns and 9520 nonzeros
# Model fingerprint: 0x2ce28b7e
# Variable types: 0 continuous, 2394 integer (2394 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 1812 rows and 1634 columns
# Presolve time: 0.03s
# Presolved: 907 rows, 760 columns, 3085 nonzeros
# Variable types: 0 continuous, 760 integer (760 binary)
#
# Root relaxation: objective 2.882132e+01, 843 iterations, 0.01 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0
#      0     0 7.2453e+07    0   48          - 7.2453e+07      -     -    0s
#      0     0 7.2458e+07    0   52          - 7.2458e+07      -     -    0s
#      0     0 7.2461e+07    0   54          - 7.2461e+07      -     -    0s
#      0     0 7.2463e+07    0   56          - 7.2463e+07      -     -    0s
#      0     0 7.2463e+07    0   56          - 7.2463e+07      -     -    0s
#      0     0 7.2475e+07    0   50          - 7.2475e+07      -     -    0s
#      0     0 7.2476e+07    0   53          - 7.2476e+07      -     -    0s
#      0     0 7.2478e+07    0   52          - 7.2478e+07      -     -    0s
#      0     0 7.2484e+07    0   52          - 7.2484e+07      -     -    0s
#      0     2 7.2487e+07    0   52          - 7.2487e+07      -     -    0s
#  73324 22910 7.6312e+07   33    6          - 7.3348e+07      -  10.2    5s
# *122022 32937              39    7.955143e+07 7.3594e+07  7.49%  10.4    7s
#  133320 34566 7.4151e+07   33   52 7.9551e+07 7.3672e+07  7.39%  10.4   10s
# H133709 33007                    7.847933e+07 7.3672e+07  6.13%  10.4   10s
#  163667 32232 7.3672e+07   49   42 7.8479e+07 7.3672e+07  6.13%  11.2   15s
#  204440 28777 7.6859e+07   52    8 7.8479e+07 7.3749e+07  6.03%  12.2   20s
#  247234 21255 7.4744e+07   59   10 7.8479e+07 7.4026e+07  5.67%  12.5   25s
#  297011 24140 infeasible   63      7.8479e+07 7.4258e+07  5.38%  12.6   30s
#  402947 32568 7.5080e+07   55   16 7.8479e+07 7.4698e+07  4.82%  12.4   40s
# *405571 25231              61    7.661283e+07 7.4710e+07  2.48%  12.4   40s
# H443457 15559                    7.582121e+07 7.4912e+07  1.20%  12.1   43s
#  454788 12406 infeasible   61      7.5821e+07 7.5036e+07  1.04%  12.0   45s
#
# Cutting planes:
#   Lift-and-project: 10
#   Cover: 76
#   Implied bound: 1
#   MIR: 198
#   StrongCG: 162
#   Flow cover: 43
#   GUB cover: 5
#   Inf proof: 1
#   Zero half: 2
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 479867 nodes (5633655 simplex iterations) in 47.07 seconds (69.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 7.58212e+07
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 7.582121400000e+07, best bound 7.582121400000e+07, gap 0.0000%
#  Saved to ../../results/IA_county_hop_optimization.csv
#
# [6/16] deviation=50 | contiguity=dist (dist: hop) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 499 rows, 396 columns and 2228 nonzeros
# Model fingerprint: 0x9d5c2075
# Variable types: 0 continuous, 396 integer (396 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+05]
#   Objective range  [1e+07, 4e+10]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 56 rows and 44 columns
# Presolve time: 0.01s
# Presolved: 443 rows, 352 columns, 1972 nonzeros
# Variable types: 0 continuous, 352 integer (352 binary)
#
# Root relaxation: objective 7.639276e+10, 85 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7.6393e+10    0    6          - 7.6393e+10      -     -    0s
#      0     0 7.6756e+10    0   18          - 7.6756e+10      -     -    0s
#      0     0 7.6764e+10    0   12          - 7.6764e+10      -     -    0s
#      0     0 7.6767e+10    0   14          - 7.6767e+10      -     -    0s
#      0     0 7.6784e+10    0   16          - 7.6784e+10      -     -    0s
#      0     0 7.6906e+10    0   28          - 7.6906e+10      -     -    0s

#
# Cutting planes:
#   Gomory: 1
#   Lift-and-project: 7
#   Cover: 444
#   MIR: 99
#   Mixing: 1
#   StrongCG: 35
#   Flow cover: 34
#   GUB cover: 6
#   Inf proof: 8
#   Zero half: 1
#   RLT: 8
#   Relax-and-lift: 1
#
# Explored 681188 nodes (7166086 simplex iterations) in 61.66 seconds (95.88 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 8.26128e+10
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 8.261283848691e+10, best bound 8.261283848691e+10, gap 0.0000%
#  Saved to ../../results/IA_county_hop_optimization.csv
#
# [7/16] deviation=50 | contiguity=dist (dist: hop) | objective_type=weighted_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 499 rows, 396 columns and 2228 nonzeros
# Model fingerprint: 0x068ec3c4
# Variable types: 0 continuous, 396 integer (396 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+05]
#   Objective range  [6e+03, 3e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 56 rows and 44 columns
# Presolve time: 0.01s
# Presolved: 443 rows, 352 columns, 1972 nonzeros
# Variable types: 0 continuous, 352 integer (352 binary)
#
# Root relaxation: objective 7.088991e+07, 93 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7.0890e+07    0    5          - 7.0890e+07      -     -    0s
#      0     0 7.2245e+07    0    6          - 7.2245e+07      -     -    0s
#      0     0 7.2245e+07    0   10          - 7.2245e+07      -     -    0s
#      0     0 7.2245e+07    0   22          - 7.2245e+07      -     -    0s
#      0     0 7.2245e+07    0    8          - 7.2245e+07      -     -    0s
#      0     0 7.2245e+07    0   20          - 7.2245e+07      -     -    0s
#      0     0 7.2245e+07    0   24          - 7.2245e+07      -     -    0s
#      0     0 7.2315e+07    0   36          - 7.2315e+07      -     -    0s
#      0     0 7.2324e+07    0   44          - 7.2324e+07      -     -    0s
#      0     0 7.2328e+07    0   38          - 7.2328e+07      -     -    0s
#      0     0 7.2402e+07    0   42          - 7.2402e+07      -     -    0s
#      0     0 7.2424e+07    0   42          - 7.2424e+07      -     -    0s
#      0     0 7.2428e+07    0   44          - 7.2428e+07      -     -    0s
#      0     0 7.2429e+07    0   52          - 7.2429e+07      -     -    0s
#      0     0 7.2431e+07    0   50          - 7.2431e+07      -     -    0s
#      0     0 7.2431e+07    0   48          - 7.2431e+07      -     -    0s
#      0     0 7.2445e+07    0   46          - 7.2445e+07      -     -    0s
#      0     0 7.2450e+07    0   38          - 7.2450e+07      -     -    0s
#      0     0 7.2452e+07    0   48          - 7.2452e+07      -     -    0s
#      0     0 7.2453e+07    0   48          - 7.2453e+07      -     -    0s
#      0     0 7.2458e+07    0   52          - 7.2458e+07      -     -    0s
#      0     0 7.2461e+07    0   54          - 7.2461e+07      -     -    0s
#      0     0 7.2463e+07    0   56          - 7.2463e+07      -     -    0s
#      0     0 7.2463e+07    0   56          - 7.2463e+07      -     -    0s
#      0     0 7.2475e+07    0   50          - 7.2475e+07      -     -    0s
#      0     0 7.2476e+07    0   53          - 7.2476e+07      -     -    0s
#      0     0 7.2478e+07    0   52          - 7.2478e+07      -     -    0s
#      0     0 7.2484e+07    0   52          - 7.2484e+07      -     -    0s
#      0     2 7.2487e+07    0   52          - 7.2487e+07      -     -    0s
#  71967 22517 7.4794e+07   35    6          - 7.3341e+07      -  10.2    5s
# *122022 32937              39    7.955143e+07 7.3594e+07  7.49%  10.4    7s
#  133347 34584 7.4061e+07   32   53 7.9551e+07 7.3672e+07  7.39%  10.4   10s
# H133709 33007                    7.847933e+07 7.3672e+07  6.13%  10.4   10s
#  169165 32335 7.4439e+07   50   17 7.8479e+07 7.3672e+07  6.13%  11.4   15s
#  222553 25865 7.4654e+07   57   26 7.8479e+07 7.3882e+07  5.86%  12.4   20s
#  273363 21381 7.7060e+07   62    8 7.8479e+07 7.4144e+07  5.52%  12.6   25s
#  323129 26670     cutoff   59      7.8479e+07 7.4374e+07  5.23%  12.6   30s
#  375452 30790 infeasible   56      7.8479e+07 7.4593e+07  4.95%  12.5   35s
# *405571 25231              61    7.661283e+07 7.4710e+07  2.48%  12.4   37s
#  420493 24414 7.4951e+07   57   23 7.6613e+07 7.4794e+07  2.37%  12.3   40s
# H443457 15559                    7.582121e+07 7.4912e+07  1.20%  12.1   43s
#  455677 12177 infeasible   61      7.5821e+07 7.5048e+07  1.02%  12.0   45s
#
# Cutting planes:
#   Lift-and-project: 10
#   Cover: 76
#   Implied bound: 1
#   MIR: 198
#   StrongCG: 162
#   Flow cover: 43
#   GUB cover: 5
#   Inf proof: 1
#   Zero half: 2
#   RLT: 2
#   Relax-and-lift: 1
#
# Explored 479867 nodes (5633655 simplex iterations) in 48.45 seconds (69.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 7.58212e+07
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 7.582121400000e+07, best bound 7.582121400000e+07, gap 0.0000%
#  Saved to ../../results/IA_county_hop_optimization.csv
#
# [8/16] deviation=50 | contiguity=dist (dist: hop) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 2719 rows, 2394 columns and 9776 nonzeros
# Model fingerprint: 0x4b3af3d9
# Variable types: 0 continuous, 2394 integer (2394 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
# Presolve removed 419 rows and 395 columns
# Presolve time: 0.04s
# Presolved: 2300 rows, 1999 columns, 8180 nonzeros
# Variable types: 0 continuous, 1999 integer (1999 binary)
#
# Root relaxation: objective 1.616670e+01, 2360 iterations, 0.09 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   16.16670    0  434          -   16.16670      -     -    0s
#      0     0   17.41255    0  444          -   17.41255      -     -    0s
#      0     0   17.70999    0  457          -   17.70999      -     -    0s
#      0     0   17.70999    0  450          -   17.70999      -     -    0s
#      0     0   17.70999    0  460          -   17.70999      -     -    0s
#      0     0   18.12093    0  503          -   18.12093      -     -    0s
#      0     0   18.13308    0  519          -   18.13308      -     -    0s
#      0     0   19.48735    0  493          -   19.48735      -     -    0s
#      0     0   21.37039    0  527          -   21.37039      -     -    1s
#      0     0   21.37039    0  527          -   21.37039      -     -    1s
#      0     2   21.37039    0  527          -   21.37039      -     -    1s
#   2663  1388   37.10350   47   50          -   30.25672      -  28.6    5s
#   9378  3256   39.41830   40   69          -   34.13098      -  52.8   10s
#  18695  6830   44.37098   44   61          -   35.27033      -  54.4   15s
# *21933  7818              47      54.0000000   35.53497  34.2%  54.3   16s
# H24629  8270                      53.0000000   35.70194  32.6%  53.1   17s
