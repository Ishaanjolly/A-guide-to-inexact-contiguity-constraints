# %% [markdown]
# ## Iowa Optimization — Hierarchical M Experiments FOR BLOCK
#
# This notebook runs multi-district MIP optimization experiments FOR BLOCK
#
# | Metric | Edge weight | M |
# |---|---|---|
# | `hop_M` | 1 + {0, M, M²} | number of nodes |
# | `euclidean_M` | eucl(i,j) + {0, M, M²} | two-sweep diameter |
#
# The penalty tier is determined by GEOID20 prefix matching:
# - `GEOID20[:11]` match → same tract (no penalty)
# - `GEOID20[:5]` match → same county, different tract (+M)
# - Otherwise → different county (+M²)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

ROOT_DIR = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT_DIR))

import os

from src.read import read_graph_from_json
from src.experiment import run_optimization_experiment

os.makedirs("../../results", exist_ok=True)

# %% [markdown]
# ### Experiment parameters

# %%
GRAPH_LEVELS = ["block"]
DISTANCE_METRICS = ["hop", "euclidean", "hop_M", "euclidean_M"]

K = 4
DEVIATIONS = [50]
CONTIGUITY = [None, "tree", "dist", "dag", "cut"]
TIME_LIMIT = 3600

OBJECTIVES = [ "euclidean_moi", "cut_edges"]

total_combinations = len(GRAPH_LEVELS) * len(DISTANCE_METRICS)
print(f"Graph levels     : {GRAPH_LEVELS}")
print(f"Distance metrics : {DISTANCE_METRICS}")
print(f"Combinations     : {total_combinations}")
print(f"Experiments each : {len(DEVIATIONS) * len(CONTIGUITY)} × objectives")
# Out:
# Graph levels     : ['block']
# Distance metrics : ['hop', 'euclidean', 'hop_M', 'euclidean_M']
# Combinations     : 4
# Experiments each : 5 × objectives

# %% [markdown]
# ### Run all combinations

# %%
all_results = {}

for graph_level in GRAPH_LEVELS:
    print(f"Loading graph: IA_{graph_level}.json")
    G = read_graph_from_json(f"../../data/IA_{graph_level}.json", state="IA")
    has_coords = "X" in G.nodes[next(iter(G.nodes))]
    coord_key = "coords" if has_coords else "no_coords"
    print(
        f"  {G.number_of_nodes()} nodes, {G.number_of_edges()} edges | coords: {has_coords}"
    )

    for dist_metric in DISTANCE_METRICS:
        label = f"IA_{graph_level}_{dist_metric}"
        results_file = f"../../results/{label}_optimization.csv"

        df = run_optimization_experiment(
            G_base=G,
            deviations=DEVIATIONS,
            contiguity_models=CONTIGUITY,
            objectives=OBJECTIVES,
            k=K,
            distance_metric=dist_metric,
            time_limit=TIME_LIMIT,
            results_file=results_file,
        )

        df["graph_level"] = graph_level
        df["distance_metric"] = dist_metric
        all_results[label] = df

print(" All combinations complete.")
# Out:
# Loading graph: IA_block.json
#   175199 nodes, 416526 edges | coords: True
# Selected roots: [36603, 68586, 152180, 11574]
# Distance metric: hop
#
# Total experiments: 10
# Results will be saved to: ../../results/IA_block_hop_optimization.csv
# ========================================================================
#
# [1/10] deviation=50 | contiguity=None (dist: N/A) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter Username
# Academic license - for non-commercial use only - expires 2027-04-02
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 175207 rows, 700796 columns and 1694196 nonzeros (Min)
# Model fingerprint: 0x1bbc87df
# Model has 496698 linear objective coefficients
# Variable types: 0 continuous, 700796 integer (700796 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [2e-05, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Found heuristic solution: objective 3.059887e+07
# Presolve removed 51026 rows and 204104 columns
# Presolve time: 3.00s
# Presolved: 124181 rows, 496692 columns, 1490076 nonzeros
# Variable types: 0 continuous, 496692 integer (496692 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.06s
#
# Barrier statistics:
#  AA' NZ     : 4.967e+05
#  Factor NZ  : 6.213e+05 (roughly 260 MB of memory)
#  Factor Ops : 3.115e+06 (less than 1 second per iteration)
#  Threads    : 22
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.24762931e+09 -9.84943877e+02  9.05e+05 1.42e-14  4.77e+03     4s
#    1   3.09964231e+08 -2.69601009e+07  1.43e+05 1.71e-13  7.77e+02     4s
#    2   2.12567294e+07 -1.66643953e+07  1.43e+03 1.71e-13  4.19e+01     4s
#    3   1.63672077e+07  2.37679375e+06  4.48e+02 3.01e-12  1.42e+01     4s
#
# Barrier performed 3 iterations in 4.46 seconds (2.97 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.29s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 9.830589e+06, 1047 iterations, 1.23 seconds (0.90 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9830589.01    0    6 3.0599e+07 9830589.01  67.9%     -    4s
# H    0     0                    9833721.5263 9830589.01  0.03%     -    4s
# H    0     0                    9830612.4567 9830589.01  0.00%     -    5s
#      0     0 9830589.03    0    8 9830612.46 9830589.03  0.00%     -    8s
#      0     0 9830589.03    0    3 9830612.46 9830589.03  0.00%     -   10s
#      0     0 9830589.04    0    5 9830612.46 9830589.04  0.00%     -   11s
# H    0     0                    9830592.5209 9830589.04  0.00%     -   11s
# H    0     0                    9830589.5986 9830589.04  0.00%     -   11s
# H    0     0                    9830589.3365 9830589.04  0.00%     -   11s
# H    0     0                    9830589.1468 9830589.04  0.00%     -   11s
#      0     0 9830589.04    0    9 9830589.15 9830589.04  0.00%     -   11s
#      0     0 9830589.05    0   13 9830589.15 9830589.05  0.00%     -   11s
#      0     0 9830589.05    0    3 9830589.15 9830589.05  0.00%     -   11s
# H    0     0                    9830589.0764 9830589.05  0.00%     -   12s
# H    0     0                    9830589.0720 9830589.05  0.00%     -   12s
#      0     0 9830589.05    0    7 9830589.07 9830589.05  0.00%     -   12s
#      0     0 9830589.05    0    3 9830589.07 9830589.05  0.00%     -   12s
#      0     0 9830589.06    0   10 9830589.07 9830589.06  0.00%     -   12s
#      0     0 9830589.06    0   15 9830589.07 9830589.06  0.00%     -   12s
#      0     0 9830589.06    0   16 9830589.07 9830589.06  0.00%     -   12s
#      0     0 9830589.07    0   19 9830589.07 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0   21 9830589.07 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0   21 9830589.07 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0   21 9830589.07 9830589.07  0.00%     -   12s
# H    0     0                    9830589.0694 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0    3 9830589.07 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0   16 9830589.07 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0   17 9830589.07 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0   18 9830589.07 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0   18 9830589.07 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0   15 9830589.07 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0   17 9830589.07 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0    2 9830589.07 9830589.07  0.00%     -   12s
#      0     0 9830589.07    0    3 9830589.07 9830589.07  0.00%     -   12s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 12
#   MIR: 12
#   StrongCG: 2
#   Zero half: 1
#
# Explored 1 nodes (1804 simplex iterations) in 12.22 seconds (10.63 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 1: 9.83059e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.830589069379e+06, best bound 9.830589069379e+06, gap 0.0000%
#  Saved to ../../results/IA_block_hop_optimization.csv
#
# [2/10] deviation=50 | contiguity=None (dist: N/A) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 4340467 rows, 4449530 columns and 15856080 nonzeros (Min)
# Model fingerprint: 0x8464979b
# Model has 416526 linear objective coefficients
# Variable types: 0 continuous, 4449530 integer (4449530 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 52 rows and 64 columns (presolve time = 5s)...
# Presolve removed 100 rows and 112 columns (presolve time = 10s)...
# Presolve removed 100 rows and 112 columns (presolve time = 15s)...
# Presolve removed 100 rows and 112 columns (presolve time = 20s)...
# Presolve removed 100 rows and 112 columns (presolve time = 25s)...
# Presolve removed 100 rows and 112 columns (presolve time = 30s)...
# Presolve removed 100 rows and 112 columns (presolve time = 35s)...
# Presolve removed 100 rows and 112 columns (presolve time = 53s)...
# Presolve removed 100 rows and 112 columns (presolve time = 55s)...
# Presolve removed 100 rows and 112 columns
# Presolve time: 59.67s
# Presolved: 4340367 rows, 4449418 columns, 15855712 nonzeros
# Variable types: 0 continuous, 4449418 integer (4449418 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Elapsed ordering time = 6s
# Elapsed ordering time = 10s
# Elapsed ordering time = 32s
# Elapsed ordering time = 35s
# Elapsed ordering time = 40s
# Ordering time: 125.98s
# Elapsed ordering time = 130s
# Elapsed ordering time = 132s
# Elapsed ordering time = 135s
# Elapsed ordering time = 150s
# Elapsed ordering time = 156s
# Elapsed ordering time = 161s
# Elapsed ordering time = 167s
# Elapsed ordering time = 171s
# Elapsed ordering time = 175s
# Elapsed ordering time = 181s
# Elapsed ordering time = 185s
# Elapsed ordering time = 190s
# Elapsed ordering time = 195s
# Elapsed ordering time = 200s
# Elapsed ordering time = 205s
# Elapsed ordering time = 210s
# Elapsed ordering time = 215s
# Elapsed ordering time = 220s
# Elapsed ordering time = 225s
# Ordering time: 238.78s
#
# Barrier statistics:
#  Dense cols : 808
#  AA' NZ     : 4.539e+07
#  Factor NZ  : 9.614e+08 (roughly 11.0 GB of memory)
#  Factor Ops : 6.684e+11 (roughly 3 seconds per iteration)
#  Threads    : 21
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.24511152e+07 -2.87547081e+06  8.15e+05 1.58e-01  6.23e+01   469s
#    1   5.20258749e+06 -3.89074126e+06  7.14e+04 1.85e+00  5.77e+00   476s
#    2   4.15238712e+05 -3.08188261e+06  1.48e-09 1.38e-01  2.86e-01   484s
#    3   3.94482956e+05 -9.96931271e+05  8.59e-10 5.17e-02  1.14e-01   494s
#    4   3.73892474e+05 -1.24372079e+05  1.28e-09 4.80e-03  4.07e-02   503s
#    5   2.19183588e+05 -1.15639366e+05  1.35e-09 2.97e-03  2.74e-02   510s
#    6   4.34023909e+04 -4.96557321e+04  8.06e-10 1.43e-03  7.61e-03   519s
#    7   8.80186204e+03 -3.82318279e+04  7.75e-10 1.12e-03  3.85e-03   526s
#    8   8.78148776e+02 -1.64422613e+03  1.23e-09 3.11e-05  2.06e-04   535s
#    9   1.33529216e+01 -4.60117095e+00  1.79e-09 1.04e-05  1.47e-06   545s
#   10   9.06775755e+00  8.92107978e+00  1.21e-09 1.73e-07  1.20e-08   553s
#   11   8.99996730e+00  8.99996642e+00  5.27e-09 6.80e-10  7.14e-14   560s
#   12   8.99996677e+00  8.99996677e+00  1.65e-09 1.64e-14  3.72e-18   569s
#
# Barrier solved model in 12 iterations and 569.36 seconds (185.67 work units)
# Optimal objective 8.99996677e+00
#
#
# Root crossover log...
#
#  3252975 DPushes remaining with DInf 0.0000000e+00               577s
#  2172305 DPushes remaining with DInf 0.0000000e+00              1101s
#  1806826 DPushes remaining with DInf 0.0000000e+00              1548s
#  1561350 DPushes remaining with DInf 0.0000000e+00              1984s
#  1378023 DPushes remaining with DInf 0.0000000e+00              2410s
#  1232916 DPushes remaining with DInf 0.0000000e+00              2767s
#  1115514 DPushes remaining with DInf 0.0000000e+00              3078s
#  1018292 DPushes remaining with DInf 1.4374126e-06              3363s
# Crossover changed status from Optimal to Time Limit
#
#
# Root relaxation: time limit, 0 iterations, 3492.48 seconds (830.86 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    194027.00000    0.00000   100%     - 3600s
#
# Explored 1 nodes (0 simplex iterations) in 3601.59 seconds (899.99 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 1: 194027
#
# Time limit reached
# Best objective 1.940270000000e+05, best bound 0.000000000000e+00, gap 100.0000%
#  Saved to ../../results/IA_block_hop_optimization.csv
#
# [3/10] deviation=50 | contiguity=tree (dist: hop) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 875999 rows, 700796 columns and 3095780 nonzeros (Min)
# Model fingerprint: 0x53439a68
# Model has 496698 linear objective coefficients
# Variable types: 0 continuous, 700796 integer (700796 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [2e-05, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 29400 rows and 29401 columns (presolve time = 5s)...
# Presolve removed 29485 rows and 29473 columns (presolve time = 10s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 15s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 20s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 25s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 30s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 35s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 40s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 45s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 50s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 55s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 60s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 65s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 70s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 75s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 80s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 85s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 90s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 95s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 100s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 105s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 110s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 115s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 120s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 125s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 130s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 135s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 140s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 145s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 150s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 155s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 160s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 165s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 170s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 175s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 180s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 185s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 190s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 195s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 200s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 205s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 210s)...
# Presolve removed 29513 rows and 29511 columns (presolve time = 224s)...
# Presolve removed 57065 rows and 57047 columns (presolve time = 225s)...
# Presolve removed 60091 rows and 58477 columns (presolve time = 230s)...
# Presolve removed 60167 rows and 58537 columns (presolve time = 235s)...
# Presolve removed 60198 rows and 58569 columns
# Presolve time: 238.37s
# Presolved: 815801 rows, 642227 columns, 2980069 nonzeros
# Variable types: 0 continuous, 642227 integer (642227 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Elapsed ordering time = 5s
# Ordering time: 8.91s
#
# Barrier statistics:
#  AA' NZ     : 4.191e+06
#  Factor NZ  : 3.109e+07 (roughly 800 MB of memory)
#  Factor Ops : 3.646e+09 (less than 1 second per iteration)
#  Threads    : 21
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.16430274e+09 -6.21780820e+05  3.34e+06 1.42e-14  2.39e+04   259s
#    1   3.57800692e+09 -2.89554915e+07  1.57e+06 1.70e+01  1.12e+04   259s
#    2   1.23905684e+08 -3.49070518e+07  4.31e+04 9.09e-13  3.43e+02   260s
#    3   6.19608806e+07 -2.19678796e+07  1.74e+04 4.55e-13  1.42e+02   260s
#    4   3.83471919e+07 -8.80070880e+06  8.20e+03 4.55e-13  6.64e+01   261s
#    5   2.71107139e+07 -2.52336089e+06  4.27e+03 4.12e-13  3.53e+01   261s
#    6   2.09935208e+07  2.62735511e+05  2.40e+03 4.26e-13  2.13e+01   262s
#    7   1.77241430e+07  3.73035241e+06  1.55e+03 4.51e-13  1.35e+01   262s
#    8   1.48289343e+07  7.14270360e+06  8.58e+02 5.19e-13  7.12e+00   263s
#    9   1.25732455e+07  8.50301752e+06  4.25e+02 5.12e-13  3.61e+00   264s
#   10   1.13986730e+07  8.97180695e+06  2.22e+02 5.66e-13  2.03e+00   264s
#   11   1.10725180e+07  9.22477704e+06  1.71e+02 5.74e-13  1.55e+00   265s
#   12   1.09309476e+07  9.34077357e+06  1.49e+02 5.59e-13  1.34e+00   265s
#   13   1.05312208e+07  9.53255989e+06  9.09e+01 6.47e-13  8.30e-01   265s
#   14   1.02064100e+07  9.68118571e+06  4.60e+01 4.61e-13  4.30e-01   266s
#      0     0 9832889.33    0   14 9832889.83 9832889.33  0.00%     -  439s
#      0     0 9832889.33    0    9 9832889.83 9832889.33  0.00%     -  439s
# H    0     0                    9832889.6300 9832889.46  0.00%     -  439s
#      0     0 9832889.46    0   10 9832889.63 9832889.46  0.00%     -  439s
#      0     0 9832889.46    0   20 9832889.63 9832889.46  0.00%     -  439s
#      0     0 9832889.46    0    4 9832889.63 9832889.46  0.00%     -  439s
#      0     0 9832889.46    0    6 9832889.63 9832889.46  0.00%     -  439s
#      0     0 9832889.51    0    3 9832889.63 9832889.51  0.00%     -  439s
#      0     0 9832889.56    0   11 9832889.63 9832889.56  0.00%     -  439s
#      0     0 9832889.56    0    2 9832889.63 9832889.56  0.00%     -  439s
#      0     0 9832889.58    0    3 9832889.63 9832889.58  0.00%     -  439s
#      0     0 9832889.58    0    6 9832889.63 9832889.58  0.00%     -  439s
# H    0     0                    9832889.6239 9832889.58  0.00%     -  439s
#      0     0 9832889.59    0    7 9832889.62 9832889.59  0.00%     -  439s
#      0     0 9832889.59    0    4 9832889.62 9832889.59  0.00%     -  439s
# H    0     0                    9832889.6208 9832889.59  0.00%     -  439s
#      0     0 9832889.59    0    2 9832889.62 9832889.59  0.00%     -  440s
# H    0     0                    9832889.6127 9832889.59  0.00%     -  440s
# H    0     0                    9832889.6059 9832889.59  0.00%     -  440s
#      0     0 9832889.59    0    9 9832889.61 9832889.59  0.00%     -  440s
#      0     0 9832889.60    0   13 9832889.61 9832889.60  0.00%     -  440s
#      0     0 9832889.60    0   16 9832889.61 9832889.60  0.00%     -  440s
#      0     0 9832889.60    0   15 9832889.61 9832889.60  0.00%     -  440s
#      0     0 9832889.60    0   15 9832889.61 9832889.60  0.00%     -  440s
#      0     0 9832889.60    0    3 9832889.61 9832889.60  0.00%     -  440s
#      0     0 infeasible    0      9832889.61 9832889.61  0.00%     -  440s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 8
#   Implied bound: 1
#   Clique: 1
#   MIR: 3
#   StrongCG: 1
#   Zero half: 1
#   RLT: 1
#   Relax-and-lift: 2
#
# Explored 1 nodes (530360 simplex iterations) in 440.18 seconds (174.30 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 1: 9.83289e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.832889605937e+06, best bound 9.832889605937e+06, gap 0.0000%
#  Saved to ../../results/IA_block_hop_optimization.csv
#
# [4/10] deviation=50 | contiguity=tree (dist: hop) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 5041259 rows, 4449530 columns and 17257664 nonzeros (Min)
# Model fingerprint: 0xecceb702
# Model has 416526 linear objective coefficients
# Variable types: 0 continuous, 4449530 integer (4449530 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 188 rows and 120 columns (presolve time = 5s)...
# Presolve removed 188 rows and 251 columns (presolve time = 10s)...
# Presolve removed 343 rows and 430 columns (presolve time = 15s)...
# Presolve removed 701048 rows and 430 columns (presolve time = 20s)...
# Presolve removed 701048 rows and 430 columns (presolve time = 25s)...
# Presolve removed 741092 rows and 741063 columns (presolve time = 30s)...
# Presolve removed 750007 rows and 750000 columns (presolve time = 36s)...
# Presolve removed 780561 rows and 780544 columns (presolve time = 41s)...
# Presolve removed 780561 rows and 780544 columns (presolve time = 45s)...
# Presolve removed 780573 rows and 780547 columns (presolve time = 50s)...
# Presolve removed 780594 rows and 780574 columns (presolve time = 55s)...
# Presolve removed 780621 rows and 780606 columns (presolve time = 60s)...
# Presolve removed 780621 rows and 780606 columns (presolve time = 65s)...
# Presolve removed 780621 rows and 780606 columns (presolve time = 70s)...
# Presolve removed 780621 rows and 780606 columns (presolve time = 75s)...
# Presolve removed 780621 rows and 780606 columns (presolve time = 80s)...
# Presolve removed 780621 rows and 780606 columns (presolve time = 85s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 96s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 100s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 105s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 110s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 115s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 120s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 125s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 130s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 135s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 140s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 145s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 150s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 155s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 160s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 165s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 170s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 175s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 180s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 185s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 190s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 195s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 200s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 205s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 210s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 215s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 220s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 225s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 230s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 235s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 240s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 245s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 250s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 255s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 260s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 265s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 270s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 275s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 280s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 285s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 290s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 295s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 300s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 305s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 310s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 315s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 320s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 325s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 330s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 335s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 340s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 345s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 350s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 355s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 360s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 365s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 370s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 375s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 380s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 385s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 390s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 395s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 400s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 405s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 410s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 415s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 420s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 425s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 430s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 435s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 440s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 445s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 450s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 455s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 460s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 465s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 470s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 475s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 480s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 485s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 490s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 495s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 500s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 505s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 510s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 515s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 520s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 525s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 530s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 535s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 540s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 545s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 550s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 555s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 560s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 565s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 570s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 575s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 580s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 585s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 590s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 595s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 600s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 605s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 610s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 615s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 620s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 625s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 630s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 635s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 640s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 645s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 650s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 655s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 660s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 665s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 670s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 675s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 680s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 685s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 690s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 695s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 700s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 705s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 710s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 715s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 720s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 725s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 730s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 735s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 740s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 745s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 750s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 755s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 760s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 765s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 770s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 775s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 780s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 785s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 790s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 795s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 800s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 805s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 810s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 815s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 820s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 825s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 830s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 835s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 840s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 845s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 850s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 855s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 860s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 865s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 870s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 875s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 880s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 885s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 890s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 895s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 900s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 905s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 910s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 915s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 920s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 925s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 930s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 935s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 940s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 945s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 950s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 955s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 960s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 965s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 970s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 975s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 980s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 985s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 990s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 995s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1000s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1005s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1010s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1015s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1020s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1025s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1030s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1035s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1040s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1045s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1050s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1055s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1060s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1065s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1070s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1075s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1080s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1085s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1090s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1095s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1100s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1105s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1110s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1115s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1120s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1125s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1130s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1135s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1140s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1145s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1150s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1155s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1160s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1165s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1170s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1175s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1180s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1185s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1190s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1195s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1200s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1205s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1210s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1215s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1220s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1225s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1230s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1235s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1240s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1245s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1250s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1255s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1260s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1265s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1270s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1275s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1280s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1285s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1290s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1295s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1300s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1305s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1310s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1315s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1320s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1325s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1330s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1335s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1340s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1345s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1350s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1355s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1360s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1365s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1370s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1375s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1380s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1385s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1390s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1395s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1400s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1405s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1410s)...
# Presolve removed 780621 rows and 780623 columns (presolve time = 1415s)...
# ...
#      0     0 9830633.93    0   16 9830633.94 9830633.93  0.00%     -  133s
# H    0     0                    9830633.9341 9830633.93  0.00%     -  133s
#      0     0 9830633.93    0   16 9830633.93 9830633.93  0.00%     -  133s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 4
#   MIR: 4
#   StrongCG: 3
#
# Explored 1 nodes (241954 simplex iterations) in 133.70 seconds (70.51 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 1: 9.83063e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 9.830633934122e+06, best bound 9.830633934122e+06, gap 0.0000%
#  Saved to ../../results/IA_block_euclidean_M_optimization.csv
#
# [8/10] deviation=50 | contiguity=dag (dist: euclidean_M) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 5041259 rows, 4449530 columns and 18222976 nonzeros (Min)
# Model fingerprint: 0xe8ec9013
# Model has 416526 linear objective coefficients
# Variable types: 0 continuous, 4449530 integer (4449530 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 76 rows and 64 columns (presolve time = 5s)...
# Presolve removed 76 rows and 64 columns (presolve time = 10s)...
# Presolve removed 122392 rows and 112 columns (presolve time = 16s)...
# Presolve removed 122392 rows and 112 columns (presolve time = 20s)...
# Presolve removed 144226 rows and 144214 columns (presolve time = 26s)...
# Presolve removed 147376 rows and 147364 columns (presolve time = 30s)...
# Presolve removed 147376 rows and 147364 columns (presolve time = 35s)...
# Presolve removed 152812 rows and 152800 columns (presolve time = 40s)...
# Presolve removed 152824 rows and 152800 columns (presolve time = 45s)...
# Presolve removed 152824 rows and 152800 columns (presolve time = 50s)...
# Presolve removed 159343 rows and 159319 columns (presolve time = 55s)...
# Presolve removed 159656 rows and 159632 columns (presolve time = 60s)...
# Presolve removed 159656 rows and 159632 columns (presolve time = 65s)...
# Presolve removed 159656 rows and 159632 columns (presolve time = 70s)...
# Presolve removed 161725 rows and 161701 columns (presolve time = 75s)...
# Presolve removed 161809 rows and 161785 columns (presolve time = 80s)...
# Presolve removed 161809 rows and 161785 columns (presolve time = 85s)...
# Presolve removed 161809 rows and 161785 columns (presolve time = 90s)...
# Presolve removed 161809 rows and 161785 columns (presolve time = 95s)...
# Presolve removed 162975 rows and 161785 columns (presolve time = 101s)...
# Presolve removed 162975 rows and 161785 columns (presolve time = 116s)...
# Presolve removed 162975 rows and 161785 columns (presolve time = 120s)...
# Presolve removed 226985 rows and 220569 columns (presolve time = 126s)...
# Presolve removed 231272 rows and 220569 columns (presolve time = 130s)...
# Presolve removed 231325 rows and 220623 columns (presolve time = 135s)...
# Presolve removed 232840 rows and 222136 columns (presolve time = 140s)...
# Presolve removed 232840 rows and 222136 columns (presolve time = 145s)...
# Presolve removed 233922 rows and 222136 columns (presolve time = 151s)...
# Presolve removed 234146 rows and 222360 columns (presolve time = 166s)...
# Presolve removed 234283 rows and 223558 columns (presolve time = 173s)...
# Presolve removed 234283 rows and 223558 columns (presolve time = 175s)...
# Presolve removed 234283 rows and 223558 columns
# Presolve time: 175.24s
# Presolved: 4806976 rows, 4225972 columns, 17207057 nonzeros
# Variable types: 0 continuous, 4225972 integer (4225972 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Elapsed ordering time = 8s
# Elapsed ordering time = 10s
# Elapsed ordering time = 15s
# Elapsed ordering time = 38s
# Elapsed ordering time = 40s
# Elapsed ordering time = 45s
# Elapsed ordering time = 50s
# Elapsed ordering time = 55s
# Ordering time: 173.72s
# Elapsed ordering time = 182s
# Elapsed ordering time = 185s
# Elapsed ordering time = 190s
# Elapsed ordering time = 216s
# Elapsed ordering time = 228s
# Elapsed ordering time = 237s
# Elapsed ordering time = 244s
# Elapsed ordering time = 246s
# Elapsed ordering time = 251s
# Elapsed ordering time = 256s
# Elapsed ordering time = 260s
# Elapsed ordering time = 266s
# Elapsed ordering time = 272s
# Elapsed ordering time = 276s
# Elapsed ordering time = 280s
# Elapsed ordering time = 286s
# Elapsed ordering time = 290s
# Elapsed ordering time = 295s
# Elapsed ordering time = 300s
# Elapsed ordering time = 305s
# Elapsed ordering time = 310s
# Elapsed ordering time = 315s
#   29   2.75373623e+04 -8.21700316e+04  3.33e-06 1.34e-05  8.94e-03  1240s
#   30   9.63862347e+03 -2.43530676e+04  2.55e-06 3.69e-06  2.77e-03  1254s
#   31   2.13569687e+03 -1.05045989e+03  7.79e-07 1.76e-07  2.60e-04  1272s
#   32   1.30568134e+02 -1.54017387e+01  5.31e-08 1.84e-08  1.19e-05  1295s
#   33   9.85907966e+00  8.77540046e+00  2.55e-10 3.38e-09  8.83e-08  1312s
#   34   9.50016927e+00  9.49969247e+00  1.71e-10 5.57e-10  3.88e-11  1325s
#   35   9.50015871e+00  9.49970244e+00  1.18e-06 5.27e-10  3.72e-11  1339s
#   36   9.50005573e+00  9.49982103e+00  1.64e-06 2.71e-10  1.91e-11  1351s
#   37   9.50001337e+00  9.49985070e+00  1.29e-06 1.99e-10  1.33e-11  1367s
#   38   9.49993913e+00  9.49993319e+00  2.33e-07 4.88e-11  4.85e-13  1379s
#   39   9.49993324e+00  9.49993324e+00  2.65e-08 9.40e-12  3.24e-16  1394s
#
# Barrier solved model in 39 iterations and 1393.69 seconds (703.34 work units)
# Optimal objective 9.49993324e+00
#
#
# Root crossover log...
#
#  1613303 variables added to crossover basis                     1400s
#
#  3191569 DPushes remaining with DInf 0.0000000e+00              1403s
#  2112618 DPushes remaining with DInf 0.0000000e+00              2218s
#  1782490 DPushes remaining with DInf 0.0000000e+00              2939s
# Crossover changed status from Optimal to Time Limit
#
#
# Root relaxation: time limit, 0 iterations, 3397.77 seconds (923.98 work units)
#
# Explored 1 nodes (0 simplex iterations) in 3600.72 seconds (1070.27 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 0.000000000000e+00, gap -
#  Saved to ../../results/IA_block_euclidean_M_optimization.csv
#
# [9/10] deviation=50 | contiguity=cut (dist: N/A) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1
#
# Optimize a model with 175207 rows, 700796 columns and 1694196 nonzeros (Min)
# Model fingerprint: 0x1bbc87df
# Model has 496698 linear objective coefficients
# Variable types: 0 continuous, 700796 integer (700796 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [2e-05, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve time: 0.05s
#
# Explored 0 nodes (0 simplex iterations) in 14241.33 seconds (0.19 work units)
# Thread count was 1 (of 32 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound -, gap -
#
# User-callback calls 37, time in user-callback 14241.11 sec
#  Saved to ../../results/IA_block_euclidean_M_optimization.csv
#
# [10/10] deviation=50 | contiguity=cut (dist: N/A) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 32 logical processors, using up to 32 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# LazyConstraints  1
# PoolSolutions  1
#
# Optimize a model with 4340467 rows, 4449530 columns and 15856080 nonzeros (Min)
# Model fingerprint: 0x8464979b
# Model has 416526 linear objective coefficients
# Variable types: 0 continuous, 4449530 integer (4449530 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 76 rows and 40 columns (presolve time = 5s)...
# Presolve removed 76 rows and 40 columns (presolve time = 10s)...
# Presolve removed 76 rows and 40 columns (presolve time = 15s)...
# Presolve removed 76 rows and 40 columns (presolve time = 20s)...
# Presolve removed 76 rows and 40 columns (presolve time = 25s)...
# Presolve removed 76 rows and 40 columns
# Presolve time: 28.57s
# Presolved: 4340391 rows, 4449490 columns, 15855808 nonzeros
# Variable types: 0 continuous, 4449490 integer (4449490 binary)
# Root relaxation presolved: 4340387 rows, 4449494 columns, 15359120 nonzeros
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Elapsed ordering time = 6s
# Elapsed ordering time = 10s
# Elapsed ordering time = 36s
# Elapsed ordering time = 40s
# Elapsed ordering time = 45s
# Ordering time: 128.48s
# Elapsed ordering time = 132s
# Elapsed ordering time = 135s
# Elapsed ordering time = 153s
# Elapsed ordering time = 159s
# Elapsed ordering time = 166s
# Elapsed ordering time = 172s
# Elapsed ordering time = 179s
# Elapsed ordering time = 180s
# Elapsed ordering time = 187s
# Elapsed ordering time = 191s
# Elapsed ordering time = 196s
# Elapsed ordering time = 201s
# Elapsed ordering time = 205s
# Elapsed ordering time = 210s
# Elapsed ordering time = 215s
# Elapsed ordering time = 220s
# Elapsed ordering time = 225s
# Elapsed ordering time = 230s
# Elapsed ordering time = 235s
# Ordering time: 240.85s
#
# Barrier statistics:
#  Dense cols : 788
#  AA' NZ     : 4.540e+07
#  Factor NZ  : 9.599e+08 (roughly 11.0 GB of memory)
#  Factor Ops : 6.670e+11 (roughly 2 seconds per iteration)
#  Threads    : 22
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.51521946e+07 -3.09212343e+06  1.39e+06 8.54e-02  1.13e+02   440s
#    1   9.04832240e+06 -4.22376561e+06  1.39e+05 2.44e+00  1.16e+01   446s
#    2   4.91295287e+05 -3.74160692e+06  1.08e+03 1.90e-01  4.22e-01   454s
#    3   3.97509900e+05 -1.45074312e+06  2.28e+01 7.64e-02  1.52e-01   463s
#    4   2.88624954e+05 -3.57837451e+04  1.94e-02 1.24e-03  2.65e-02   474s
#    5   1.76175094e+04 -2.58080044e+04  9.39e-04 1.16e-04  3.55e-03   484s
#    6   1.30089446e+03 -6.37369577e+03  2.01e-05 2.65e-05  6.27e-04   491s
#    7   4.24550650e+01 -7.79286033e+01  3.27e-07 1.60e-05  9.84e-06   499s
#    8   1.05656418e+01  8.35517268e+00  5.90e-09 3.77e-08  1.81e-07   506s
#    9   8.99996843e+00  8.99995787e+00  6.86e-10 8.49e-12  8.63e-13   513s
#   10   8.99996677e+00  8.99996677e+00  2.76e-09 5.43e-14  7.66e-18   520s
#
# Barrier solved model in 10 iterations and 520.12 seconds (135.26 work units)
# Optimal objective 8.99996677e+00
#
#
# Root crossover log...
#
#  3252973 DPushes remaining with DInf 0.0000000e+00               527s
#  2172083 DPushes remaining with DInf 0.0000000e+00              1023s
#  1806729 DPushes remaining with DInf 4.4701842e-06              1470s
#  1561428 DPushes remaining with DInf 4.3201138e-06              1906s
#  1378034 DPushes remaining with DInf 2.0685406e-06              2312s
#  1232936 DPushes remaining with DInf 2.5841652e-06              2685s
#  1114759 DPushes remaining with DInf 0.0000000e+00              3028s
#  1017815 DPushes remaining with DInf 0.0000000e+00              3490s
# Crossover changed status from Optimal to Time Limit
#
#
# Root relaxation: time limit, 0 iterations, 3527.05 seconds (788.30 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0               -    0.00000      -     - 3600s
#
# Explored 1 nodes (0 simplex iterations) in 3600.58 seconds (822.21 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 0
#
# Time limit reached
# Best objective -, best bound 0.000000000000e+00, gap -
#
# User-callback calls 9961, time in user-callback 0.15 sec
#  Saved to ../../results/IA_block_euclidean_M_optimization.csv
#  All combinations complete.
