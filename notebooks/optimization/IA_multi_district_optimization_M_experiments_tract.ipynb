# %% [markdown]
# ## Iowa Optimization — Hierarchical M Experiments TRACT
#
# This notebook runs multi-district MIP optimization experiments FOR TRACT
#
# | Metric | Edge weight | M |
# |---|---|---|
# | `hop_M` | 1 + {0, M, M²} | number of nodes |
# | `euclidean_M` | eucl(i,j) + {0, M, M²} | two-sweep diameter |
#
# The penalty tier is determined by GEOID20 prefix matching:
# - `GEOID20[:11]` match → same tract (no penalty)
# - `GEOID20[:5]` match → same county, different tract (+M)
# - Otherwise → different county (+M²)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

ROOT_DIR = Path.cwd().parents[1]
sys.path.insert(0, str(ROOT_DIR))

import os

from src.read import read_graph_from_json
from src.experiment import run_optimization_experiment

os.makedirs("../../results", exist_ok=True)

# %% [markdown]
# ### Experiment parameters

# %%
GRAPH_LEVELS = ["tract"]
DISTANCE_METRICS = ["hop", "euclidean", "hop_M", "euclidean_M"]

K = 4
DEVIATIONS = [50]
CONTIGUITY = ["tree", "dist", "dag", "cut"]
TIME_LIMIT = 3600

OBJECTIVES = [ "euclidean_moi", "cut_edges"]

total_combinations = len(GRAPH_LEVELS) * len(DISTANCE_METRICS)
print(f"Graph levels     : {GRAPH_LEVELS}")
print(f"Distance metrics : {DISTANCE_METRICS}")
print(f"Combinations     : {total_combinations}")
print(f"Experiments each : {len(DEVIATIONS) * len(CONTIGUITY)} × objectives")
# Out:
# Graph levels     : ['tract']
# Distance metrics : ['hop', 'euclidean', 'hop_M', 'euclidean_M']
# Combinations     : 4
# Experiments each : 4 × objectives

# %% [markdown]
# ### Run all combinations

# %%
all_results = {}

for graph_level in GRAPH_LEVELS:
    print(f"Loading graph: IA_{graph_level}.json")
    G = read_graph_from_json(f"../../data/IA_{graph_level}.json", state="IA")
    has_coords = "X" in G.nodes[next(iter(G.nodes))]
    coord_key = "coords" if has_coords else "no_coords"
    print(
        f"  {G.number_of_nodes()} nodes, {G.number_of_edges()} edges | coords: {has_coords}"
    )

    for dist_metric in DISTANCE_METRICS:
        label = f"IA_{graph_level}_{dist_metric}"
        results_file = f"../../results/{label}_optimization.csv"

        df = run_optimization_experiment(
            G_base=G,
            deviations=DEVIATIONS,
            contiguity_models=CONTIGUITY,
            objectives=OBJECTIVES,
            k=K,
            distance_metric=dist_metric,
            time_limit=TIME_LIMIT,
            results_file=results_file,
        )

        df["graph_level"] = graph_level
        df["distance_metric"] = dist_metric
        all_results[label] = df

print(" All combinations complete.")
# Out:
# Loading graph: IA_tract.json
#   896 nodes, 2348 edges | coords: True
# Selected roots: [780, 808, 475, 209]
# Distance metric: hop
#
# Total experiments: 8
# Results will be saved to: ../../results/IA_tract_hop_optimization.csv
# ========================================================================
#
# [1/8] deviation=50 | contiguity=tree (dist: hop) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-11-24
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 4484 rows, 3584 columns and 17896 nonzeros (Min)
# Model fingerprint: 0xdf1f1a14
# Model has 3572 linear objective coefficients
# Variable types: 0 continuous, 3584 integer (3584 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [5e-01, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed
8736166.53 8734267.53  0.02%     -    0s
#      0     0 8734267.53    0   18 8736166.53 8734267.53  0.02%     -    0s
#      0     0 8734270.36    0   19 8736166.53 8734270.36  0.02%     -    0s
#      0     0 8734371.32    0   18 8736166.53 8734371.32  0.02%     -    0s
#      0     0 8734400.77    0   17 8736166.53 8734400.77  0.02%     -    0s
#      0     0 8734411.48    0   18 8736166.53 8734411.48  0.02%     -    0s
#      0     0 8734553.21    0   22 8736166.53 8734553.21  0.02%     -    0s
#      0     0 8734569.92    0   22 8736166.53 8734569.92  0.02%     -    0s
#      0     2 8734577.13    0   22 8736166.53 8734577.13  0.02%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Lift-and-project: 1
#   Cover: 12
#   MIR: 32
#   StrongCG: 12
#   GUB cover: 4
#   RLT: 1
#
# Explored 239 nodes (2970 simplex iterations) in 0.66 seconds (0.39 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 8.73617e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 8.736166534991e+06, best bound 8.736166534991e+06, gap 0.0000%
#  Saved to ../../results/IA_tract_hop_optimization.csv
#
# [2/8] deviation=50 | contiguity=tree (dist: hop) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 27964 rows, 24716 columns and 97728 nonzeros (Min)
# Model fingerprint: 0x548e27f5
# Model has 2348 linear objective coefficients
# Variable types: 0 continuous, 24716 integer (24716 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 13941 rows and 12875 columns
# Presolve time: 0.62s
# Presolved: 14023 rows, 11841 columns, 47147 nonzeros
# Variable types: 0 continuous, 11841 integer (11841 binary)
#
# Root relaxation: objective 5.673560e+01, 32382 iterations, 3.73 seconds (5.40 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   56.73560    0 1606          -   56.73560      -     -    4s
# H    0     0                    1341.0000000   56.74136  95.8%     -    5s
#      0     0   57.26699    0 1402 1341.00000   57.26699  95.7%     -    6s
# H    0     0                    1048.0000000   57.26699  94.5%     -    6s
# H    0     0                     815.0000000   57.26699  93.0%     -    6s
# H    0     0                     236.0000000   57.26699  75.7%     -    6s
#      0     0   58.72491    0 1521  236.00000   58.72491  75.1%     -    7s
#      0     0   58.98912    0 1560  236.00000   58.98912  75.0%     -    8s
#      0     0   58.98912    0 1560  236.00000   58.98912  75.0%     -    8s
#      0     0   58.98933    0 1692  236.00000   58.98933  75.0%     -   12s
# H    0     0                     235.0000000   58.98933  74.9%     -   12s
# H    0     0                     234.0000000   58.98933  74.8%     -   12s
#      0     0   58.98933    0 1531  234.00000   58.98933  74.8%     -   14s
# H    0     0                     180.0000000   58.98933  67.2%     -   14s
# H    0     0                     147.0000000   58.98933  59.9%     -   14s
#      0     0   59.54087    0 1549  147.00000   59.54087  59.5%     -   15s
#      0     0   60.84717    0 1756  147.00000   60.84717  58.6%     -   15s
#      0     0   60.84717    0 1761  147.00000   60.84717  58.6%     -   15s
#      0     0   60.84717    0 1782  147.00000   60.84717  58.6%     -   16s
#      0     0   60.84717    0 1782  147.00000   60.84717  58.6%     -   16s
#      0     0   60.84717    0 1782  147.00000   60.84717  58.6%     -   16s
#      0     2   60.84717    0 1782  147.00000   60.84717  58.6%     -   16s
#     62    71   72.29320    8  650  147.00000   63.19799  57.0%   574   20s
# H  325   329                     135.0000000   63.19799  53.2%   271   21s
# H  356   353                     134.0000000   63.19799  52.8%   252   21s
# H  749   570                     129.9999990   63.32292  51.3%   199   23s
work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 82
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 8.200000000000e+01, best bound 8.200000000000e+01, gap 0.0000%
#  Saved to ../../results/IA_tract_hop_optimization.csv
#
# [3/8] deviation=50 | contiguity=dist (dist: hop) | objective_type=euclidean_moi
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 4484 rows, 3584 columns and 20151 nonzeros (Min)
# Model fingerprint: 0x7842fd68
# Model has 3572 linear objective coefficients
# Variable types: 0 continuous, 3584 integer (3584 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [5e-01, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 724 rows and 599 columns
# Presolve time: 0.27s
# Presolved: 3760 rows, 2985 columns, 16898 nonzeros
# Variable types: 0 continuous, 2985 integer (2985 binary)
#
# Root relaxation: objective 8.700741e+06, 732 iterations, 0.02 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8700741.17    0   24          - 8700741.17      -     -    0s
# H    0     0                    8756737.5821 8700741.17  0.64%     -    0s
# H    0     0                    8739049.2439 8700741.17  0.44%     -    0s
# H    0     0                    8728920.4706 8700741.17  0.32%     -    0s
# H    0     0                    8725196.2222 8700741.17  0.28%     -    0s
# H    0     0                    8721986.8666 8700741.17  0.24%     -    0s
# H    0     0                    8714531.2758 8700741.17  0.16%     -    0s
# H    0     0                    8713377.5512 8706093.83  0.08%     -    0s
# H    0     0                    8713373.0274 8706093.83  0.08%     -    0s
#      0     0 8706093.83    0   26 8713373.03 8706093.83  0.08%     -    0s
#      0     0 8706093.83    0    6 8713373.03 8706093.83  0.08%     -    0s
#      0     0 8706093.83    0    9 8713373.03 8706093.83  0.08%     -    0s
#      0     0 8706093.83    0   10 8713373.03 8706093.83  0.08%     -    0s
#      0     0 8706093.83    0   12 8713373.03 8706093.83  0.08%     -    0s
#      0     0 8706093.83    0   12 8713373.03 8706093.83  0.08%     -    0s
# H    0     0                    8710757.8498 8706093.83  0.05%     -    0s
#      0     0 8706093.83    0   13 8710757.85 8706093.83  0.05%     -    0s
#      0     0 8706093.83    0    6 8710757.85 8706093.83  0.05%     -    0s
#      0     0 8706093.83    0   11 8710757.85 8706093.83  0.05%     -    0s
#      0     0 8706093.83    0   15 8710757.85 8706093.83  0.05%     -    0s
#      0     0 8706093.83    0   12 8710757.85 8706093.83  0.05%     -    0s
#      0     0 8706093.83    0   15 8710757.85 8706093.83  0.05%     -    0s
#      0     0 8706093.83    0   15 8710757.85 8706093.83  0.05%     -    0s
#      0     0 8706093.83    0   18 8710757.85 8706093.83  0.05%     -    0s
#      0     0 8706093.83    0   22 8710757.85 8706093.83  0.05%     -    0s
#      0     0 8706093.83    0   22 8710757.85 8706093.83  0.05%     -    0s
#      0     0 8706093.83    0   30 8710757.85 8706093.83  0.05%     -    0s
#      0     0 8706121.83    0   33 8710757.85 8706121.83  0.05%     -    0s
#      0     0 8706566.60    0   20 8710757.85 8706566.60  0.05%     -    0s
#      0     0 8706566.60    0   20 8710757.85 8706566.60  0.05%     -    0s
#      0     0 8706566.60    0   20 8710757.85 8706566.60  0.05%     -    0s
#      0     0 8706633.81    0    5 8710757.85 8706633.81  0.05%     -    0s
#      0     0 8706633.81    0   12 8710757.85 8706633.81  0.05%     -    0s
#      0     0 8706633.81    0   17 8710757.85 8706633.81  0.05%     -    0s
#      0     0 8706633.81    0   29 8710757.85 8706633.81  0.05%     -    0s
#      0     0 8706633.81    0   17 8710757.85 8706633.81  0.05%     -    0s
#      0     0 8706633.81    0   22 8710757.85 8706633.81  0.05%     -    0s
#      0     0 8706633.81    0   19 8710757.85 8706633.81  0.05%     -    0s
#      0     0 8706633.81    0   19 8710757.85 8706633.81  0.05%     -    0s
#      0     0 8706633.81    0   26 8710757.85 8706633.81  0.05%     -    0s
#      0     0 8706633.81    0   25 8710757.85 8706633.81  0.05%     -    0s
# H    0     0                    8709519.3102 8706633.81  0.03%     -    0s
#      0     0 8706633.81    0   29 8709519.31 8706633.81  0.03%     -    0s
#      0     0 8706774.52    0   29 8709519.31 8706774.52  0.03%     -    0s
#      0     0 8706885.61    0   37 8709519.31 8706885.61  0.03%     -    0s
#      0     0 8706894.87    0   32 8709519.31 8706894.87  0.03%     -    0s
#      0     0 8707017.20    0   31 8709519.31 8707017.20  0.03%     -    0s
#      0     0 8707017.20    0    5 8709519.31 8707017.20  0.03%     -    0s
#      0     0 8707017.20    0   12 8709519.31 8707017.20  0.03%     -    0s
#      0     0 8707017.20    0   24 8709519.31 8707017.20  0.03%     -    0s
#      0     0 8707017.20    0   16 8709519.31 8707017.20  0.03%     -    0s
#      0     0 8707017.20    0   24 8709519.31 8707017.20  0.03%     -    0s
#      0     0 8707022.40    0   29 8709519.31 8707022.40  0.03%     -    0s
#      0     0 8707039.34    0   28 8709519.31 8707039.34  0.03%     -    0s
#      0     0 8707041.08    0   28 8709519.31 8707041.08  0.03%     -    0s
#      0     0 8707089.22    0   34 8709519.31 8707089.22  0.03%     -    0s
#      0     0 8707117.67    0   37 8709519.31 8707117.67  0.03%     -    0s
#      0     0 8707177.62    0   30 8709519.31 8707177.62  0.03%     -    0s
#      0     0 8707225.09    0   31 8709519.31 8707225.09  0.03%     -    0s
#      0     0 8707245.99    0   33 8709519.31 8707245.99  0.03%     -    0s
#      0     0 8707251.65    0   34 8709519.31 8707251.65  0.03%     -    0s
#      0     0 8707265.18    0   33 8709519.31 8707265.18  0.03%     -    0s
#      0     0 8707271.83    0   33 8709519.31 8707271.83  0.03%     -    0s
#      0     0 8707271.83    0   33 8709519.31 8707271.83  0.03%     -    0s
#      0     0 8707276.16    0    5 8709519.31 8707276.16  0.03%     -    0s
#      0     0 8707276.16    0   12 8709519.31 8707276.16  0.03%     -    0s
#      0     0 8707276.16    0   16 8709519.31 8707276.16  0.03%     -    0s
#      0     0 8707276.16    0   17 8709519.31 8707276.16  0.03%     -    0s
#      0     0 8707276.16    0   19 8709519.31 8707276.16  0.03%     -    0s
#      0     0 8707276.16    0   22 8709519.31 8707276.16  0.03%     -    0s
#      0     0 8707276.16    0   25 8709519.31 8707276.16  0.03%     -    0s
#      0     0 8707276.16    0   27 8709519.31 8707276.16  0.03%     -    0s
#      0     0 8707276.16    0   29 8709519.31 8707276.16  0.03%     -    0s
#      0     0 8707287.99    0   26 8709519.31 8707287.99  0.03%     -    0s
#      0     0 8707292.07    0   28 8709519.31 8707292.07  0.03%     -    0s
#      0     0 8707323.28    0   33 8709519.31 8707323.28  0.03%     -    0s
#      0     0 8707324.80    0   33 8709519.31 8707324.80  0.03%     -    0s
#      0     2 8707324.80    0   33 8709519.31 8707324.80  0.03%     -    0s
#
# Cutting planes:
#   Lift-and-project: 1
#   Cover: 45
#   MIR: 28
#   StrongCG: 24
#   Inf proof: 9
#   RLT: 8
#
# Explored 2849 nodes (18154 simplex iterations) in 1.10 seconds (0.62 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 8.70952e+06
#
# Optimal solution found (tolerance 0.00e+00)
# Best objective 8.709519310167e+06, best bound 8.709519310167e+06, gap 0.0000%
#  Saved to ../../results/IA_tract_hop_optimization.csv
#
# [4/8] deviation=50 | contiguity=dist (dist: hop) | objective_type=cut_edges
# Using L, U, k = 797543 797642 4
# Set parameter OutputFlag to value 1
# Set parameter LogToConsole to value 1
# Set parameter MIPGap to value 0
# Set parameter PoolSearchMode to value 0
# Set parameter PoolSolutions to value 1
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (mac64[arm] - Darwin 22.6.0 22H730)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  3600
# MIPGap  0
# PoolSolutions  1
#
# Optimize a model with 27964 rows, 24716 columns and 99983 nonzeros (Min)
# Model fingerprint: 0x47d7f431
# Model has 2348 linear objective coefficients
# Variable types: 0 continuous, 24716 integer (24716 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+05]
#
# Presolve removed 5125 rows and 4830 columns
# Presolve time: 0.58s
# Presolved: 22839 rows, 19886 columns, 80741 nonzeros
# Variable types: 0 continuous, 19886 integer (19886 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    17423    7.0953244e+00   2.116674e+05   0.000000e+00      5s
